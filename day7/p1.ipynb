# %%
with open('sample.txt') as f:
    lines = [line.strip() for line in f.readlines()]
lines[:5]
# Out:
# ['32T3K 765', 'T55J5 684', 'KK677 28', 'KTJJT 220', 'QQQJA 483']

# %%
with open('file.txt') as f:
    lines = [line.strip() for line in f.readlines()]
lines[:5]
# Out:
# ['7227Q 52', '67Q64 732', '33Q33 573', '58ATQ 939', '93K53 840']

# %%
parsed = [line.split() for line in lines]
parsed
# Out:
# [['7227Q', '52'],
#  ['67Q64', '732'],
#  ['33Q33', '573'],
#  ['58ATQ', '939'],
#  ['93K53', '840'],
#  ['55AJ8', '496'],
#  ['6ATAT', '863'],
#  ['26J77', '1'],
#  ['TTQAT', '381'],
#  ['2J2J2', '322'],
#  ['342Q2', '409'],
#  ['3444Q', '864'],
#  ['77J67', '31'],
#  ['772QJ', '796'],
#  ['5388J', '956'],
#  ['7JJ7J', '88'],
#  ['5Q555', '626'],
#  ['77AK8', '588'],
#  ['J2222', '661'],
#  ['36T93', '934'],
#  ['5Q365', '343'],
#  ['K3K3K', '283'],
#  ['5959A', '537'],
#  ['44477', '560'],
#  ['6AA5K', '208'],
#  ['5J445', '262'],
#  ['28228', '61'],
#  ['646A6', '503'],
#  ['KK4Q8', '471'],
#  ['A426T', '500'],
#  ['AQ9JA', '643'],
#  ['J784T', '348'],
#  ['22J48', '6'],
#  ['A5AJ5', '220'],
#  ['62235', '545'],
#  ['84JJJ', '206'],
#  ['48464', '669'],
#  ['44844', '637'],
#  ['Q8537', '969'],
#  ['95663', '751'],
#  ['JTQK7', '305'],
#  ['33TTT', '335'],
#  ['4T925', '32'],
#  ['9777Q', '738'],
#  ['2QQ66', '971'],
#  ['TQQ9T', '657'],
#  ['69437', '176'],
#  ['2555J', '849'],
#  ['55AAA', '26'],
#  ['94TT4', '531'],
#  ['89T66', '55'],
#  ['387J8', '663'],
#  ['KKKKJ', '198'],
#  ['K4KK4', '870'],
#  ['622J2', '330'],
#  ['6283A', '337'],
#  ['JQQQ2', '349'],
#  ['666AA', '706'],
#  ['9794J', '966'],
#  ['99A9T', '771'],
#  ['53J53', '477'],
#  ['7JT3J', '829'],
#  ['KK524', '765'],
#  ['Q4QQ4', '486'],
#  ['J7367', '519'],
#  ['KK4TJ', '937'],
#  ['Q4983', '168'],
#  ['74A77', '997'],
#  ['Q2244', '464'],
#  ['242J4', '625'],
#  ['J2839', '326'],
#  ['T927T', '773'],
#  ['2Q992', '875'],
#  ['77722', '467'],
#  ['8K645', '959'],
#  ['AJTJ3', '650'],
#  ['64Q35', '98'],
#  ['QQTQ4', '973'],
#  ['24492', '438'],
#  ['T8AK7', '983'],
#  ['K439T', '924'],
#  ['7AJ7J', '426'],
#  ['T88T5', '801'],
#  ['9J939', '267'],
#  ['7K557', '458'],
#  ['T9KQ3', '231'],
#  ['34444', '720'],
#  ['44TTT', '781'],
#  ['AA3A9', '177'],
#  ['78878', '479'],
#  ['4K474', '932'],
#  ['3TT65', '634'],
#  ['98898', '113'],
#  ['26286', '702'],
#  ['37736', '673'],
#  ['9Q9K3', '103'],
#  ['9TT92', '755'],
#  ['8AAJ8', '845'],
#  ['55A55', '356'],
#  ['K2222', '184'],
#  ['7777Q', '950'],
#  ['64392', '649'],
#  ['36653', '891'],
#  ['22AA2', '201'],
#  ['55943', '367'],
#  ['AQA2Q', '178'],
#  ['4T693', '806'],
#  ['385J5', '429'],
#  ['246Q6', '930'],
#  ['32J2Q', '428'],
#  ['59Q83', '128'],
#  ['8684Q', '828'],
#  ['482Q9', '668'],
#  ['243QA', '250'],
#  ['JQTQQ', '656'],
#  ['45645', '354'],
#  ['7J648', '534'],
#  ['44633', '638'],
#  ['A3283', '284'],
#  ['38262', '830'],
#  ['QAT67', '976'],
#  ['7662Q', '241'],
#  ['266T2', '355'],
#  ['3AA67', '958'],
#  ['JTTTT', '51'],
#  ['A3T22', '739'],
#  ['6A45J', '978'],
#  ['969JJ', '965'],
#  ['69K98', '413'],
#  ['8Q33Q', '239'],
#  ['886QQ', '135'],
#  ['Q44JK', '525'],
#  ['TT6TT', '64'],
#  ['77773', '451'],
#  ['8AKK8', '172'],
#  ['QTQ2T', '872'],
#  ['QQTQ7', '642'],
#  ['44666', '387'],
#  ['J4Q74', '225'],
#  ['4J968', '542'],
#  ['Q6939', '831'],
#  ['2773T', '420'],
#  ['55565', '313'],
#  ['76666', '9'],
#  ['5J4J4', '212'],
#  ['TTJQJ', '601'],
#  ['358K2', '725'],
#  ['JQ78Q', '597'],
#  ['3K3TK', '685'],
#  ['QKQQQ', '261'],
#  ['5Q59Q', '762'],
#  ['Q77QQ', '756'],
#  ['KK2J2', '728'],
#  ['TKKK5', '879'],
#  ['9KQ9K', '785'],
#  ['Q83JK', '96'],
#  ['39998', '256'],
#  ['TTJ3T', '852'],
#  ['66866', '192'],
#  ['2567T', '211'],
#  ['76969', '20'],
#  ['KAKKK', '735'],
#  ['9Q5QQ', '808'],
#  ['JQ87K', '67'],
#  ['J8887', '320'],
#  ['J9763', '36'],
#  ['A6464', '75'],
#  ['K5AA5', '996'],
#  ['TTJ7T', '890'],
#  ['7KKK7', '450'],
#  ['72752', '817'],
#  ['K2J32', '915'],
#  ['T25J7', '72'],
#  ['QQ6Q6', '53'],
#  ['27T7J', '577'],
#  ['98J89', '236'],
#  ['23525', '404'],
#  ['44244', '34'],
#  ['2K8J7', '509'],
#  ['AK427', '108'],
#  ['7K6KA', '466'],
#  ['374J7', '553'],
#  ['533K3', '78'],
#  ['8J6K2', '301'],
#  ['J7577', '995'],
#  ['T88T8', '903'],
#  ['626K6', '265'],
#  ['2A96A', '462'],
#  ['T4987', '279'],
#  ['JJTKJ', '69'],
#  ['77767', '641'],
#  ['2Q232', '210'],
#  ['444JJ', '133'],
#  ['7Q7JQ', '508'],
#  ['5555K', '888'],
#  ['46462', '874'],
#  ['KQKKK', '474'],
#  ['96737', '10'],
#  ['7AT28', '234'],
#  ['2QJTA', '229'],
#  ['9T8T8', '111'],
#  ['373KJ', '263'],
#  ['95599', '605'],
#  ['A7Q66', '719'],
#  ['82555', '291'],
#  ['9KK8T', '810'],
#  ['Q87KK', '102'],
#  ['TT2TT', '792'],
#  ['888T8', '772'],
#  ['9J767', '972'],
#  ['9496J', '774'],
#  ['4KJ44', '511'],
#  ['KA5KK', '790'],
#  ['4J222', '944'],
#  ['2325A', '961'],
#  ['AQJ5A', '118'],
#  ['J555J', '698'],
#  ['9899J', '862'],
#  ['5496K', '590'],
#  ['A97J4', '287'],
#  ['77JA3', '695'],
#  ['959Q9', '79'],
#  ['29927', '516'],
#  ['K88A3', '400'],
#  ['9997J', '541'],
#  ['58A6J', '452'],
#  ['2QTKA', '447'],
#  ['777KK', '154'],
#  ['47J2K', '907'],
#  ['QJ5A4', '592'],
#  ['JAA8J', '730'],
#  ['K5J55', '982'],
#  ['3QQQ3', '85'],
#  ['725QK', '140'],
#  ['5KK55', '678'],
#  ['A5AQ9', '871'],
#  ['3J639', '149'],
#  ['99899', '623'],
#  ['7AAA7', '152'],
#  ['7777J', '401'],
#  ['75492', '895'],
#  ['TQ549', '900'],
#  ['2A7TT', '991'],
#  ['2J36J', '559'],
#  ['95K83', '433'],
#  ['44TTA', '778'],
#  ['98J9Q', '378'],
#  ['55TQ9', '581'],
#  ['3AK7T', '50'],
#  ['94399', '869'],
#  ['Q43JA', '109'],
#  ['34KKJ', '569'],
#  ['88499', '27'],
#  ['22525', '737'],
#  ['7T9K6', '523'],
#  ['337J9', '141'],
#  ['99959', '339'],
#  ['JK9K9', '444'],
#  ['5T55T', '680'],
#  ['339T9', '562'],
#  ['JJKKK', '366'],
#  ['KJTJK', '814'],
#  ['9KJ55', '299'],
#  ['5969J', '672'],
#  ['92273', '416'],
#  ['6TQ68', '107'],
#  ['T36K5', '938'],
#  ['K26K6', '884'],
#  ['5625J', '93'],
#  ['44393', '196'],
#  ['55558', '100'],
#  ['96666', '521'],
#  ['4938T', '813'],
#  ['2QQ8Q', '244'],
#  ['8887T', '885'],
#  ['KT92Q', '189'],
#  ['6K766', '60'],
#  ['67676', '481'],
#  ['QQ524', '427'],
#  ['58598', '520'],
#  ['4J454', '777'],
#  ['6Q82Q', '303'],
#  ['6Q6J3', '435'],
#  ['83993', '670'],
#  ['32232', '873'],
#  ['T488T', '795'],
#  ['622J6', '893'],
#  ['53323', '914'],
#  ['J77J7', '205'],
#  ['55954', '385'],
#  ['KJK48', '251'],
#  ['96AQK', '861'],
#  ['QJT45', '653'],
#  ['K3826', '835'],
#  ['44447', '546'],
#  ['4T877', '793'],
#  ['88333', '701'],
#  ['QQQJ8', '566'],
#  ['36663', '799'],
#  ['66Q5Q', '41'],
#  ['A44Q9', '43'],
#  ['47KKK', '783'],
#  ['23J22', '3'],
#  ['67JQQ', '289'],
#  ['K43J7', '484'],
#  ['QJQQQ', '89'],
#  ['32T65', '709'],
#  ['4646T', '515'],
#  ['T3A29', '535'],
#  ['75665', '952'],
#  ['KQQ2T', '837'],
#  ['AJTT4', '578'],
#  ['QK4Q4', '288'],
#  ['6J6JJ', '312'],
#  ['28887', '138'],
#  ['33TK4', '599'],
#  ['77J2J', '946'],
#  ['566J5', '63'],
#  ['333A5', '457'],
#  ['A2A66', '575'],
#  ['6296T', '611'],
#  ['3TQ46', '373'],
#  ['J888J', '726'],
#  ['KKJ4K', '948'],
#  ['J5T4A', '455'],
#  ['4T74T', '962'],
#  ['473A8', '431'],
#  ['ATATA', '514'],
#  ['4Q385', '269'],
#  ['K65K6', '383'],
#  ['398K4', '715'],
#  ['65JT7', '630'],
#  ['8A6J9', '419'],
#  ['QA5JQ', '585'],
#  ['Q45KA', '754'],
#  ['AAA66', '173'],
#  ['4949Q', '733'],
#  ['K9972', '22'],
#  ['KTKKK', '422'],
#  ['5JQ22', '502'],
#  ['K787K', '302'],
#  ['TT8TJ', '527'],
#  ['265KA', '363'],
#  ['KK7KK', '745'],
#  ['6263K', '498'],
#  ['65J2K', '565'],
#  ['26322', '104'],
#  ['44Q74', '731'],
#  ['23383', '276'],
#  ['KQ948', '687'],
#  ['9552J', '504'],
#  ['75JA6', '95'],
#  ['3JJ33', '994'],
#  ['28824', '716'],
#  ['2A8JK', '13'],
#  ['22868', '38'],
#  ['88388', '987'],
#  ['A955Q', '963'],
#  ['54T86', '547'],
#  ['55547', '671'],
#  ['5TK7Q', '417'],
#  ['4Q35K', '842'],
#  ['33353', '492'],
#  ['96A85', '878'],
#  ['Q6QAQ', '867'],
#  ['K55KJ', '822'],
#  ['97QK2', '398'],
#  ['K6229', '162'],
#  ['4TT84', '518'],
#  ['Q67AJ', '628'],
#  ['2TT22', '776'],
#  ['2QJ24', '766'],
#  ['A8TT8', '418'],
#  ['A74Q2', '704'],
#  ['77T7T', '399'],
#  ['774JT', '789'],
#  ['6A845', '371'],
#  ['8JQ5Q', '970'],
#  ['55645', '757'],
#  ['68788', '896'],
#  ['5J2J7', '350'],
#  ['K88J6', '853'],
#  ['3AAA3', '160'],
#  ['3J777', '125'],
#  ['3666K', '247'],
#  ['5QA98', '887'],
#  ['QJ272', '106'],
#  ['45555', '767'],
#  ['3T3T3', '441'],
#  ['4448T', '260'],
#  ['A9A9A', '550'],
#  ['76JA6', '591'],
#  ['6T4T8', '984'],
#  ['KT7JK', '748'],
#  ['727T2', '253'],
#  ['8Q77A', '364'],
#  ['Q8448', '507'],
#  ['T3JJ9', '707'],
#  ['8Q88Q', '555'],
#  ['A84AA', '370'],
#  ['7QQ26', '804'],
#  ['35377', '616'],
#  ['TK3KK', '87'],
#  ['T764T', '688'],
#  ['AT9A8', '45'],
#  ['A6AA5', '328'],
#  ['57T63', '315'],
#  ['62622', '627'],
#  ['66366', '788'],
#  ['JKQKQ', '980'],
#  ['6T5AQ', '841'],
#  ['58585', '693'],
#  ['3KA73', '411'],
#  ['44884', '949'],
#  ['AA958', '615'],
#  ['4Q26A', '886'],
#  ['57AJ7', '564'],
#  ['84J48', '342'],
#  ['633TJ', '295'],
#  ['29222', '606'],
#  ['Q222Q', '453'],
#  ['JAQAA', '818'],
#  ['T6TTJ', '290'],
#  ['Q3KAJ', '563'],
#  ['666TT', '844'],
#  ['K28QQ', '286'],
#  ['KK46K', '811'],
#  ['T2222', '714'],
#  ['8A883', '463'],
#  ['JJ73J', '83'],
#  ['AJK26', '538'],
#  ['72A34', '266'],
#  ['TKK9Q', '877'],
#  ['333AA', '382'],
#  ['8T28T', '470'],
#  ['888A5', '910'],
#  ['5A365', '664'],
#  ['88JKK', '310'],
#  ['55235', '551'],
#  ['K2KKK', '308'],
#  ['AA688', '809'],
#  ['62T6Q', '57'],
#  ['AA2A4', '336'],
#  ['9999K', '268'],
#  ['44J8T', '227'],
#  ['67877', '461'],
#  ['K33QK', '21'],
#  ['Q44JQ', '423'],
#  ['TK787', '71'],
#  ['A78A6', '749'],
#  ['QJAQQ', '331'],
#  ['J2A52', '935'],
#  ['965TT', '54'],
#  ['598J5', '729'],
#  ['K8KKJ', '857'],
#  ['K5J6K', '340'],
#  ['QJQ22', '47'],
#  ['685QA', '230'],
#  ['9999J', '617'],
#  ['A9339', '321'],
#  ['953T4', '920'],
#  ['33373', '859'],
#  ['8JJ8T', '922'],
#  ['42K39', '116'],
#  ['QQ432', '449'],
#  ['K24K2', '345'],
#  ['4A442', '802'],
#  ['3JKK3', '758'],
#  ['6JTTQ', '185'],
#  ['5K9J7', '124'],
#  ['7A779', '325'],
#  ['68868', '998'],
#  ['JQ355', '224'],
#  ['TK456', '568'],
#  ['93793', '150'],
#  ['449J9', '33'],
#  ['57777', '248'],
#  ['666KK', '750'],
#  ['T333J', '703'],
#  ['466AA', '613'],
#  ['5JJ8Q', '226'],
#  ['AQTQT', '779'],
#  ['33355', '23'],
#  ['33TQ3', '974'],
#  ['8J588', '992'],
#  ['KJKKQ', '832'],
#  ['34J97', '694'],
#  ['K9993', '70'],
#  ['QQQ9Q', '228'],
#  ['4K9AQ', '148'],
#  ['7KKJ9', '379'],
#  ['99944', '571'],
#  ['TT3Q8', '297'],
#  ['T2QA9', '921'],
#  ['JJ55T', '561'],
#  ['J6KAQ', '607'],
#  ['4735Q', '259'],
#  ['3J547', '223'],
#  ['64464', '574'],
#  ['77J94', '919'],
#  ['626Q6', '923'],
#  ['J3832', '631'],
#  ['96QK3', '391'],
#  ['A4J4A', '421'],
#  ['J77KK', '723'],
#  ['K8354', '285'],
#  ['JATQ9', '273'],
#  ['28732', '209'],
#  ['72779', '666'],
#  ['4J255', '243'],
#  ['777K7', '202'],
#  ['JJQ5J', '645'],
#  ['82A47', '612'],
#  ['888T4', '97'],
#  ['22K2K', '736'],
#  ['T35Q8', '752'],
#  ['94238', '700'],
#  ['5K242', '324'],
#  ['5QJ5A', '927'],
#  ['4T6KA', '892'],
#  ['74J8A', '960'],
#  ['4J4JK', '791'],
#  ['A76QQ', '159'],
#  ['988A8', '143'],
#  ['86J32', '39'],
#  ['7QK32', '512'],
#  ['7TTTT', '483'],
#  ['KK27K', '252'],
#  ['8A366', '529'],
#  ['8333J', '182'],
#  ['52QQ5', '164'],
#  ['95926', '219'],
#  ['AK33A', '977'],
#  ['A368K', '988'],
#  ['QQA5Q', '858'],
#  ['5999J', '848'],
#  ['KK9JK', '110'],
#  ['6Q2Q2', '570'],
#  ['AAKK7', '600'],
#  ['555Q3', '277'],
#  ['2A2A6', '614'],
#  ['38853', '2'],
#  ['JTA82', '608'],
#  ['8J668', '636'],
#  ['J999K', '30'],
#  ['QJ35T', '505'],
#  ['AQ7AA', '121'],
#  ['777KJ', '389'],
#  ['J6282', '465'],
#  ['8K2T3', '332'],
#  ['43Q82', '760'],
#  ['66T6K', '734'],
#  ['7A77A', '454'],
#  ['A98AA', '99'],
#  ['QQ7QQ', '362'],
#  ['99J9J', '129'],
#  ['444TJ', '74'],
#  ['A7263', '16'],
#  ['74749', '699'],
#  ['2K2KK', '137'],
#  ['8K6JQ', '146'],
#  ['6TJ58', '902'],
#  ['72222', '123'],
#  ['9A97A', '415'],
#  ['37TT6', '380'],
#  ['88882', '651'],
#  ['66555', '311'],
#  ['55J55', '270'],
#  ['77A72', '430'],
#  ['33Q5Q', '193'],
#  ['TTQ44', '369'],
#  ['3TT8T', '278'],
#  ['428T3', '132'],
#  ['AK897', '214'],
#  ['7QQQJ', '697'],
#  ['9AK62', '157'],
#  ['96466', '487'],
#  ['J522J', '238'],
#  ['9J7A9', '394'],
#  ['QQK77', '584'],
#  ['Q72T4', '24'],
#  ['26662', '169'],
#  ['9KK32', '908'],
#  ['45QJ6', '576'],
#  ['45QKJ', '690'],
#  ['KK248', '696'],
#  ['AAAA4', '652'],
#  ['2T2QQ', '681'],
#  ['9992J', '216'],
#  ['47777', '929'],
#  ['KJT5J', '73'],
#  ['5TA64', '593'],
#  ['55AA5', '780'],
#  ['7QT35', '58'],
#  ['8JTJ6', '648'],
#  ['K4K54', '712'],
#  ['44Q49', '539'],
#  ['KT427', '665'],
#  ['TJ3T3', '191'],
#  ['T7758', '945'],
#  ['A9347', '609'],
#  ['942J2', '386'],
#  ['QQ9J9', '81'],
#  ['J7445', '957'],
#  ['7A54J', '889'],
#  ['QK44K', '207'],
#  ['7KJ99', '683'],
#  ['7888Q', '925'],
#  ['44J44', '583'],
#  ['365K8', '794'],
#  ['88983', '675'],
#  ['2T2QJ', '375'],
#  ['28K2J', '222'],
#  ['84A8T', '372'],
#  ['72796', '264'],
#  ['3KKAK', '708'],
#  ['59559', '722'],
#  ['7JK35', '5'],
#  ['J8Q88', '913'],
#  ['QA543', '942'],
#  ['86A68', '866'],
#  ['T4A4A', '746'],
#  ['QAQQQ', '640'],
#  ['J8T8T', '408'],
#  ['77JT6', '679'],
#  ['J5779', '323'],
#  ['86AA3', '803'],
#  ['TAAA3', '376'],
#  ['5J6K5', '217'],
#  ['78253', '787'],
#  ['TTTK3', '357'],
#  ['Q8599', '368'],
#  ['QTTTT', '199'],
#  ['77K3K', '309'],
#  ['TKJKK', '644'],
#  ['7Q554', '307'],
#  ['KKQKQ', '445'],
#  ['77866', '403'],
#  ['44355', '272'],
#  ['J6969', '968'],
#  ['985A3', '667'],
#  ['JJQQQ', '333'],
#  ['5J9JT', '281'],
#  ['6T4A4', '156'],
#  ['KA9J2', '999'],
#  ['22329', '405'],
#  ['3QK93', '692'],
#  ['2T2TT', '827'],
#  ['22999', '240'],
#  ['TK7JJ', '101'],
#  ['7287A', '567'],
#  ['J4J24', '360'],
#  ['AAJ53', '424'],
#  ['JAA45', '769'],
#  ['77282', '981'],
#  ['7777T', '548'],
#  ['43533', '572'],
#  ['93932', '180'],
#  ['7AAAA', '926'],
#  ['8K888', '782'],
#  ['4747J', '495'],
#  ['684QJ', '40'],
#  ['73495', '855'],
#  ['2552J', '293'],
#  ['7QKT2', '497'],
#  ['AA4A6', '163'],
#  ['2T8TT', '897'],
#  ['7J746', '407'],
#  ['3J234', '807'],
#  ['Q3QQQ', '358'],
#  ['AJAJA', '66'],
#  ['8K5Q5', '115'],
#  ['K9TTJ', '485'],
#  ['33Q7Q', '186'],
#  ['T7797', '604'],
#  ['69989', '443'],
#  ['J666T', '11'],
#  ['J2233', '532'],
#  ['94969', '410'],
#  ['889Q8', '17'],
#  ['K97A6', '298'],
#  ['73T3J', '334'],
#  ['663J6', '821'],
#  ['54QQT', '770'],
#  ['4AAA4', '432'],
#  ['4334A', '967'],
#  ['JJJJJ', '647'],
#  ['JK2TT', '904'],
#  ['2774A', '280'],
#  ['K8KJA', '834'],
#  ['AJ38A', '763'],
#  ['3KKKJ', '836'],
#  ['69693', '1000'],
#  ['48J47', '955'],
#  ['7KA7K', '905'],
#  ['33244', '691'],
#  ['5A435', '557'],
#  ['87KA8', '472'],
#  ['J2484', '341'],
#  ['K35K5', '815'],
#  ['K8Q2A', '29'],
#  ['KK3Q4', '390'],
#  ['7J77A', '300'],
#  ['84T5T', '589'],
#  ['7893T', '964'],
#  ['22AAA', '235'],
#  ['QKK6Q', '142'],
#  ['T6A48', '122'],
#  ['T22T9', '167'],
#  ['KA53Q', '686'],
#  ['68J5K', '947'],
#  ['64625', '727'],
#  ['3T5T3', '120'],
#  ['2992J', '846'],
#  ['A3K8J', '145'],
#  ['QK99J', '838'],
#  ['4A4AQ', '91'],
#  ['KKK8K', '491'],
#  ['AAA28', '480'],
#  ['42772', '304'],
#  ['T222A', '204'],
#  ['K6Q37', '558'],
#  ['Q5K6A', '352'],
#  ['8QJQ8', '682'],
#  ['832J8', '147'],
#  ['Q388T', '170'],
#  ['9555J', '12'],
#  ['7KTT9', '658'],
#  ['KAAKK', '911'],
#  ['TKTTT', '174'],
#  ['44TJ2', '993'],
#  ['6KK6K', '136'],
#  ['5A5TA', '494'],
#  ['AAJ22', '15'],
#  ['633Q3', '740'],
#  ['QQQ4Q', '933'],
#  ['4A4Q2', '237'],
#  ['33555', '402'],
#  ['Q9A23', '549'],
#  ['3Q343', '936'],
#  ['9Q799', '14'],
#  ['3KKKQ', '618'],
#  ['JKK54', '876'],
#  ['96996', '25'],
#  ['2T374', '439'],
#  ['4QJAQ', '374'],
#  ['JQ64K', '718'],
#  ['464Q6', '187'],
#  ['J9252', '271'],
#  ['88Q38', '396'],
#  ['K4J55', '912'],
#  ['5JT73', '434'],
#  ['KK6J4', '195'],
#  ['A8AAA', '388'],
#  ['79793', '353'],
#  ['877J7', '943'],
#  ['J4484', '662'],
#  ['A434J', '812'],
#  ['TTQJ7', '493'],
#  ['63333', '711'],
#  ['22262', '540'],
#  ['474QQ', '975'],
#  ['Q22K2', '393'],
#  ['K5KK2', '621'],
#  ['QQ62T', '524'],
#  ['J6666', '188'],
#  ['AAQAA', '883'],
#  ['65666', '126'],
#  ['778K8', '65'],
#  ['8A3T9', '90'],
#  ['AA392', '392'],
#  ['T593T', '151'],
#  ['QQ2KK', '654'],
#  ['765KA', '953'],
#  ['Q5QQ7', '475'],
#  ['4KTK4', '677'],
#  ['66243', '580'],
#  ['895TJ', '175'],
#  ['QT345', '436'],
#  ['3332T', '865'],
#  ['2T5J9', '414'],
#  ['24J9K', '181'],
#  ['5557A', '249'],
#  ['J3J5J', '513'],
#  ['75555', '741'],
#  ['659T2', '689'],
#  ['TQ5TJ', '530'],
#  ['7T48A', '194'],
#  ['23332', '629'],
#  ['KJKK6', '490'],
#  ['43J33', '344'],
#  ['K55KK', '624'],
#  ['A8JAA', '622'],
#  ['68J89', '880'],
#  ['KJQT9', '44'],
#  ['98989', '526'],
#  ['Q3QT4', '602'],
#  ['764QQ', '134'],
#  ['772Q7', '127'],
#  ['6K6T5', '274'],
#  ['383Q8', '139'],
#  ['JK677', '764'],
#  ['TTT4T', '56'],
#  ['76K82', '153'],
#  ['JAAAA', '717'],
#  ['33JJ5', '684'],
#  ['8TTKT', '985'],
#  ['8T74T', '928'],
#  ['88J88', '916'],
#  ['74938', '660'],
#  ['3TK74', '338'],
#  ['T98K5', '397'],
#  ['99A69', '488'],
#  ['24A6K', '197'],
#  ['43A42', '144'],
#  ['TT9J9', '579'],
#  ['J837Q', '552'],
#  ['44464', '820'],
#  ['82A5A', '329'],
#  ['ATAAJ', '183'],
#  ['83899', '190'],
#  ['88TQT', '292'],
#  ['69482', '130'],
#  ['36J36', '4'],
#  ['458T7', '860'],
#  ['4Q29Q', '473'],
#  ['KKK4K', '676'],
#  ['4K756', '800'],
#  ['8J8JJ', '898'],
#  ['TTTT9', '881'],
#  ['88J28', '203'],
#  ['42422', '744'],
#  ['QQQKK', '112'],
#  ['4J2Q7', '327'],
#  ['57922', '582'],
#  ['44A44', '37'],
#  ['35559', '705'],
#  ['T8TQQ', '246'],
#  ['JQ29K', '536'],
#  ['9A999', '825'],
#  ['62TT2', '499'],
#  ['K3567', '218'],
#  ['72J22', '215'],
#  ['87487', '377'],
#  ['5J655', '489'],
#  ['26769', '816'],
#  ['577A7', '851'],
#  ['44T86', '131'],
#  ['7QQ72', '460'],
#  ['28QJ3', '954'],
#  ['243K7', '979'],
#  ['24J97', '724'],
#  ['4QKT3', '742'],
#  ['A88AA', '619'],
#  ['363AA', '610'],
#  ['T24TJ', '117'],
#  ['92AJ6', '587'],
#  ['J666J', '596'],
#  ['Q7J36', '850'],
#  ['Q3968', '901'],
#  ['8J7JK', '798'],
#  ['5J9T3', '84'],
#  ['29Q22', '674'],
#  ['5588J', '598'],
#  ['7747T', '833'],
#  ['735A6', '384'],
#  ['44944', '68'],
#  ['44J26', '365'],
#  ['52555', '77'],
#  ['Q4TT3', '476'],
#  ['K88TK', '440'],
#  ['6JJTT', '632'],
#  ['KTA54', '759'],
#  ['KKT5T', '254'],
#  ['A85A5', '80'],
#  ['96J6J', '469'],
#  ['9KKKK', '556'],
#  ['37733', '18'],
#  ['KJJ66', '282'],
#  ['2Q882', '989'],
#  ['JJ8JJ', '868'],
#  ['TTJTJ', '603'],
#  ['AKAAA', '710'],
#  ['J6TT6', '49'],
#  ['Q7JT7', '448'],
#  ['8T728', '319'],
#  ['86J55', '161'],
#  ['8K5KK', '805'],
#  ['KKATT', '459'],
#  ['T929J', '743'],
#  ['2238J', '86'],
#  ['99929', '119'],
#  ['82Q5T', '314'],
#  ['22297', '7'],
#  ['Q58QQ', '437'],
#  ['8A8Q5', '46'],
#  ['87J2Q', '761'],
#  ['T2A35', '823'],
#  ['9TQQQ', '395'],
#  ['2KT69', '232'],
#  ['5T566', '506'],
#  ['J33QQ', '179'],
#  ['2T652', '275'],
#  ['KT228', '909'],
#  ['9T229', '82'],
#  ['TA696', '986'],
#  ['Q3585', '317'],
#  ['AQKAA', '42'],
#  ['J9JJ9', '713'],
#  ['QQ448', '951'],
#  ['T664T', '786'],
#  ['J2J5J', '824'],
#  ['67677', '635'],
#  ['QQQQT', '899'],
#  ['333J3', '442'],
#  ['Q2QQ2', '753'],
#  ['8K79T', '917'],
#  ['J82A2', '839'],
#  ['T5TTT', '155'],
#  ['4K4Q8', '721'],
#  ['A7JAJ', '306'],
#  ['4Q44Q', '940'],
#  ['2J6KJ', '854'],
#  ['77979', '59'],
#  ['57575', '296'],
#  ['QK66Q', '166'],
#  ['Q5QQK', '257'],
#  ['8Q5J2', '528'],
#  ['TKJ27', '882'],
#  ['TT7T5', '843'],
#  ['2227A', '94'],
#  ['45784', '594'],
#  ['AQK97', '468'],
#  ['98TTT', '446'],
#  ['2886T', '346'],
#  ['JAA66', '826'],
#  ['44333', '478'],
#  ['A33J3', '114'],
#  ['Q82T6', '620'],
#  ['J833Q', '165'],
#  ['4T98J', '105'],
#  ['44499', '775'],
#  ['Q5Q5Q', '245'],
#  ['37477', '931'],
#  ['28QKT', '655'],
#  ['3K388', '213'],
#  ['J3838', '19'],
#  ['83444', '48'],
#  ['7TTAT', '316'],
#  ['87777', '768'],
#  ['KJTK5', '639'],
#  ['QQQ27', '200'],
#  ['22299', '797'],
#  ['99K9A', '412'],
#  ['44454', '586'],
#  ['J689T', '894'],
#  ['86888', '294'],
#  ['TATTA', '456'],
#  ['24452', '517'],
#  ['54Q42', '62'],
#  ['T97TT', '646'],
#  ['QJAAJ', '533'],
#  ['23K8Q', '359'],
#  ['AAJ5A', '941'],
#  ['59985', '747'],
#  ['6TT55', '510'],
#  ['Q6892', '784'],
#  ['Q66Q7', '595'],
#  ['A2223', '28'],
#  ['6989J', '221'],
#  ['944A6', '659'],
#  ['7K524', '171'],
#  ['49498', '544'],
#  ['55Q29', '8'],
#  ['8A787', '351'],
#  ['A7Q7Q', '242'],
#  ['92444', '406'],
#  ['558J2', '255'],
#  ['7JT77', '258'],
#  ['493K9', '233'],
#  ['7A333', '501'],
#  ['9TQ9Q', '554'],
#  ['J92KT', '76'],
#  ['9TJ67', '522'],
#  ['43443', '906'],
#  ['9TTT9', '92'],
#  ['66266', '918'],
#  ['AKKAA', '543'],
#  ['7ATJJ', '361'],
#  ['K86J6', '482'],
#  ['22422', '633'],
#  ['AAATQ', '318'],
#  ['64637', '856'],
#  ['72777', '347'],
#  ['6QQ66', '158'],
#  ['37377', '990'],
#  ['A8624', '35'],
#  ['27276', '847'],
#  ['22954', '425'],
#  ['TK4JT', '819']]

# %%
scores = []
for hand, bid in parsed:
    cards = {}
    for card in hand:
        if card in cards:
            cards[card] += 1
        else:
            cards[card] = 1
    matches = sorted(cards.values(), reverse=True)
    score = 0
    if matches[0] == 5:
        score = 7
    elif matches[0] == 4:
        score = 6
    elif matches[0] == 3 and matches[1] == 2:
        score = 5
    elif matches[0] == 3:
        score = 4
    elif matches[0] == 2 and matches[1] == 2:
        score = 3
    elif matches[0] == 2:
        score = 2
    else:
        score = 1

    scores.append((score, hand, bid))
        
    print(cards)

print(scores)
# Out:
# {'7': 2, '2': 2, 'Q': 1}
# {'6': 2, '7': 1, 'Q': 1, '4': 1}
# {'3': 4, 'Q': 1}
# {'5': 1, '8': 1, 'A': 1, 'T': 1, 'Q': 1}
# {'9': 1, '3': 2, 'K': 1, '5': 1}
# {'5': 2, 'A': 1, 'J': 1, '8': 1}
# {'6': 1, 'A': 2, 'T': 2}
# {'2': 1, '6': 1, 'J': 1, '7': 2}
# {'T': 3, 'Q': 1, 'A': 1}
# {'2': 3, 'J': 2}
# {'3': 1, '4': 1, '2': 2, 'Q': 1}
# {'3': 1, '4': 3, 'Q': 1}
# {'7': 3, 'J': 1, '6': 1}
# {'7': 2, '2': 1, 'Q': 1, 'J': 1}
# {'5': 1, '3': 1, '8': 2, 'J': 1}
# {'7': 2, 'J': 3}
# {'5': 4, 'Q': 1}
# {'7': 2, 'A': 1, 'K': 1, '8': 1}
# {'J': 1, '2': 4}
# {'3': 2, '6': 1, 'T': 1, '9': 1}
# {'5': 2, 'Q': 1, '3': 1, '6': 1}
# {'K': 3, '3': 2}
# {'5': 2, '9': 2, 'A': 1}
# {'4': 3, '7': 2}
# {'6': 1, 'A': 2, '5': 1, 'K': 1}
# {'5': 2, 'J': 1, '4': 2}
# {'2': 3, '8': 2}
# {'6': 3, '4': 1, 'A': 1}
# {'K': 2, '4': 1, 'Q': 1, '8': 1}
# {'A': 1, '4': 1, '2': 1, '6': 1, 'T': 1}
# {'A': 2, 'Q': 1, '9': 1, 'J': 1}
# {'J': 1, '7': 1, '8': 1, '4': 1, 'T': 1}
# {'2': 2, 'J': 1, '4': 1, '8': 1}
# {'A': 2, '5': 2, 'J': 1}
# {'6': 1, '2': 2, '3': 1, '5': 1}
# {'8': 1, '4': 1, 'J': 3}
# {'4': 3, '8': 1, '6': 1}
# {'4': 4, '8': 1}
# {'Q': 1, '8': 1, '5': 1, '3': 1, '7': 1}
# {'9': 1, '5': 1, '6': 2, '3': 1}
# {'J': 1, 'T': 1, 'Q': 1, 'K': 1, '7': 1}
# {'3': 2, 'T': 3}
# {'4': 1, 'T': 1, '9': 1, '2': 1, '5': 1}
# {'9': 1, '7': 3, 'Q': 1}
# {'2': 1, 'Q': 2, '6': 2}
# {'T': 2, 'Q': 2, '9': 1}
# {'6': 1, '9': 1, '4': 1, '3': 1, '7': 1}
# {'2': 1, '5': 3, 'J': 1}
# {'5': 2, 'A': 3}
# {'9': 1, '4': 2, 'T': 2}
# {'8': 1, '9': 1, 'T': 1, '6': 2}
# {'3': 1, '8': 2, '7': 1, 'J': 1}
# {'K': 4, 'J': 1}
# {'K': 3, '4': 2}
# {'6': 1, '2': 3, 'J': 1}
# {'6': 1, '2': 1, '8': 1, '3': 1, 'A': 1}
# {'J': 1, 'Q': 3, '2': 1}
# {'6': 3, 'A': 2}
# {'9': 2, '7': 1, '4': 1, 'J': 1}
# {'9': 3, 'A': 1, 'T': 1}
# {'5': 2, '3': 2, 'J': 1}
# {'7': 1, 'J': 2, 'T': 1, '3': 1}
# {'K': 2, '5': 1, '2': 1, '4': 1}
# {'Q': 3, '4': 2}
# {'J': 1, '7': 2, '3': 1, '6': 1}
# {'K': 2, '4': 1, 'T': 1, 'J': 1}
# {'Q': 1, '4': 1, '9': 1, '8': 1, '3': 1}
# {'7': 3, '4': 1, 'A': 1}
# {'Q': 1, '2': 2, '4': 2}
# {'2': 2, '4': 2, 'J': 1}
# {'J': 1, '2': 1, '8': 1, '3': 1, '9': 1}
# {'T': 2, '9': 1, '2': 1, '7': 1}
# {'2': 2, 'Q': 1, '9': 2}
# {'7': 3, '2': 2}
# {'8': 1, 'K': 1, '6': 1, '4': 1, '5': 1}
# {'A': 1, 'J': 2, 'T': 1, '3': 1}
# {'6': 1, '4': 1, 'Q': 1, '3': 1, '5': 1}
# {'Q': 3, 'T': 1, '4': 1}
# {'2': 2, '4': 2, '9': 1}
# {'T': 1, '8': 1, 'A': 1, 'K': 1, '7': 1}
# {'K': 1, '4': 1, '3': 1, '9': 1, 'T': 1}
# {'7': 2, 'A': 1, 'J': 2}
# {'T': 2, '8': 2, '5': 1}
# {'9': 3, 'J': 1, '3': 1}
# {'7': 2, 'K': 1, '5': 2}
# {'T': 1, '9': 1, 'K': 1, 'Q': 1, '3': 1}
# {'3': 1, '4': 4}
# {'4': 2, 'T': 3}
# {'A': 3, '3': 1, '9': 1}
# {'7': 2, '8': 3}
# {'4': 3, 'K': 1, '7': 1}
# {'3': 1, 'T': 2, '6': 1, '5': 1}
# {'9': 2, '8': 3}
# {'2': 2, '6': 2, '8': 1}
# {'3': 2, '7': 2, '6': 1}
# {'9': 2, 'Q': 1, 'K': 1, '3': 1}
# {'9': 2, 'T': 2, '2': 1}
# {'8': 2, 'A': 2, 'J': 1}
# {'5': 4, 'A': 1}
# {'K': 1, '2': 4}
# {'7': 4, 'Q': 1}
# {'6': 1, '4': 1, '3': 1, '9': 1, '2': 1}
# {'3': 2, '6': 2, '5': 1}
# {'2': 3, 'A': 2}
# {'5': 2, '9': 1, '4': 1, '3': 1}
# {'A': 2, 'Q': 2, '2': 1}
# {'4': 1, 'T': 1, '6': 1, '9': 1, '3': 1}
# {'3': 1, '8': 1, '5': 2, 'J': 1}
# {'2': 1, '4': 1, '6': 2, 'Q': 1}
# {'3': 1, '2': 2, 'J': 1, 'Q': 1}
# {'5': 1, '9': 1, 'Q': 1, '8': 1, '3': 1}
# {'8': 2, '6': 1, '4': 1, 'Q': 1}
# {'4': 1, '8': 1, '2': 1, 'Q': 1, '9': 1}
# {'2': 1, '4': 1, '3': 1, 'Q': 1, 'A': 1}
# {'J': 1, 'Q': 3, 'T': 1}
# {'4': 2, '5': 2, '6': 1}
# {'7': 1, 'J': 1, '6': 1, '4': 1, '8': 1}
# {'4': 2, '6': 1, '3': 2}
# {'A': 1, '3': 2, '2': 1, '8': 1}
# {'3': 1, '8': 1, '2': 2, '6': 1}
# {'Q': 1, 'A': 1, 'T': 1, '6': 1, '7': 1}
# {'7': 1, '6': 2, '2': 1, 'Q': 1}
# {'2': 2, '6': 2, 'T': 1}
# {'3': 1, 'A': 2, '6': 1, '7': 1}
# {'J': 1, 'T': 4}
# {'A': 1, '3': 1, 'T': 1, '2': 2}
# {'6': 1, 'A': 1, '4': 1, '5': 1, 'J': 1}
# {'9': 2, '6': 1, 'J': 2}
# {'6': 1, '9': 2, 'K': 1, '8': 1}
# {'8': 1, 'Q': 2, '3': 2}
# {'8': 2, '6': 1, 'Q': 2}
# {'Q': 1, '4': 2, 'J': 1, 'K': 1}
# {'T': 4, '6': 1}
# {'7': 4, '3': 1}
# {'8': 2, 'A': 1, 'K': 2}
# {'Q': 2, 'T': 2, '2': 1}
# {'Q': 3, 'T': 1, '7': 1}
# {'4': 2, '6': 3}
# {'J': 1, '4': 2, 'Q': 1, '7': 1}
# {'4': 1, 'J': 1, '9': 1, '6': 1, '8': 1}
# {'Q': 1, '6': 1, '9': 2, '3': 1}
# {'2': 1, '7': 2, '3': 1, 'T': 1}
# {'5': 4, '6': 1}
# {'7': 1, '6': 4}
# {'5': 1, 'J': 2, '4': 2}
# {'T': 2, 'J': 2, 'Q': 1}
# {'3': 1, '5': 1, '8': 1, 'K': 1, '2': 1}
# {'J': 1, 'Q': 2, '7': 1, '8': 1}
# {'3': 2, 'K': 2, 'T': 1}
# {'Q': 4, 'K': 1}
# {'5': 2, 'Q': 2, '9': 1}
# {'Q': 3, '7': 2}
# {'K': 2, '2': 2, 'J': 1}
# {'T': 1, 'K': 3, '5': 1}
# {'9': 2, 'K': 2, 'Q': 1}
# {'Q': 1, '8': 1, '3': 1, 'J': 1, 'K': 1}
# {'3': 1, '9': 3, '8': 1}
# {'T': 3, 'J': 1, '3': 1}
# {'6': 4, '8': 1}
# {'2': 1, '5': 1, '6': 1, '7': 1, 'T': 1}
# {'7': 1, '6': 2, '9': 2}
# {'K': 4, 'A': 1}
# {'9': 1, 'Q': 3, '5': 1}
# {'J': 1, 'Q': 1, '8': 1, '7': 1, 'K': 1}
# {'J': 1, '8': 3, '7': 1}
# {'J': 1, '9': 1, '7': 1, '6': 1, '3': 1}
# {'A': 1, '6': 2, '4': 2}
# {'K': 1, '5': 2, 'A': 2}
# {'T': 3, 'J': 1, '7': 1}
# {'7': 2, 'K': 3}
# {'7': 2, '2': 2, '5': 1}
# {'K': 1, '2': 2, 'J': 1, '3': 1}
# {'T': 1, '2': 1, '5': 1, 'J': 1, '7': 1}
# {'Q': 3, '6': 2}
# {'2': 1, '7': 2, 'T': 1, 'J': 1}
# {'9': 2, '8': 2, 'J': 1}
# {'2': 2, '3': 1, '5': 2}
# {'4': 4, '2': 1}
# {'2': 1, 'K': 1, '8': 1, 'J': 1, '7': 1}
# {'A': 1, 'K': 1, '4': 1, '2': 1, '7': 1}
# {'7': 1, 'K': 2, '6': 1, 'A': 1}
# {'3': 1, '7': 2, '4': 1, 'J': 1}
# {'5': 1, '3': 3, 'K': 1}
# {'8': 1, 'J': 1, '6': 1, 'K': 1, '2': 1}
# {'J': 1, '7': 3, '5': 1}
# {'T': 2, '8': 3}
# {'6': 3, '2': 1, 'K': 1}
# {'2': 1, 'A': 2, '9': 1, '6': 1}
# {'T': 1, '4': 1, '9': 1, '8': 1, '7': 1}
# {'J': 3, 'T': 1, 'K': 1}
# {'7': 4, '6': 1}
# {'2': 3, 'Q': 1, '3': 1}
# {'4': 3, 'J': 2}
# {'7': 2, 'Q': 2, 'J': 1}
# {'5': 4, 'K': 1}
# {'4': 2, '6': 2, '2': 1}
# {'K': 4, 'Q': 1}
# {'9': 1, '6': 1, '7': 2, '3': 1}
# {'7': 1, 'A': 1, 'T': 1, '2': 1, '8': 1}
# {'2': 1, 'Q': 1, 'J': 1, 'T': 1, 'A': 1}
# {'9': 1, 'T': 2, '8': 2}
# {'3': 2, '7': 1, 'K': 1, 'J': 1}
# {'9': 3, '5': 2}
# {'A': 1, '7': 1, 'Q': 1, '6': 2}
# {'8': 1, '2': 1, '5': 3}
# {'9': 1, 'K': 2, '8': 1, 'T': 1}
# {'Q': 1, '8': 1, '7': 1, 'K': 2}
# {'T': 4, '2': 1}
# {'8': 4, 'T': 1}
# {'9': 1, 'J': 1, '7': 2, '6': 1}
# {'9': 2, '4': 1, '6': 1, 'J': 1}
# {'4': 3, 'K': 1, 'J': 1}
# {'K': 3, 'A': 1, '5': 1}
# {'4': 1, 'J': 1, '2': 3}
# {'2': 2, '3': 1, '5': 1, 'A': 1}
# {'A': 2, 'Q': 1, 'J': 1, '5': 1}
# {'J': 2, '5': 3}
# {'9': 3, '8': 1, 'J': 1}
# {'5': 1, '4': 1, '9': 1, '6': 1, 'K': 1}
# {'A': 1, '9': 1, '7': 1, 'J': 1, '4': 1}
# {'7': 2, 'J': 1, 'A': 1, '3': 1}
# {'9': 3, '5': 1, 'Q': 1}
# {'2': 2, '9': 2, '7': 1}
# {'K': 1, '8': 2, 'A': 1, '3': 1}
# {'9': 3, '7': 1, 'J': 1}
# {'5': 1, '8': 1, 'A': 1, '6': 1, 'J': 1}
# {'2': 1, 'Q': 1, 'T': 1, 'K': 1, 'A': 1}
# {'7': 3, 'K': 2}
# {'4': 1, '7': 1, 'J': 1, '2': 1, 'K': 1}
# {'Q': 1, 'J': 1, '5': 1, 'A': 1, '4': 1}
# {'J': 2, 'A': 2, '8': 1}
# {'K': 1, '5': 3, 'J': 1}
# {'3': 2, 'Q': 3}
# {'7': 1, '2': 1, '5': 1, 'Q': 1, 'K': 1}
# {'5': 3, 'K': 2}
# {'A': 2, '5': 1, 'Q': 1, '9': 1}
# {'3': 2, 'J': 1, '6': 1, '9': 1}
# {'9': 4, '8': 1}
# {'7': 2, 'A': 3}
# {'7': 4, 'J': 1}
# {'7': 1, '5': 1, '4': 1, '9': 1, '2': 1}
# {'T': 1, 'Q': 1, '5': 1, '4': 1, '9': 1}
# {'2': 1, 'A': 1, '7': 1, 'T': 2}
# {'2': 1, 'J': 2, '3': 1, '6': 1}
# {'9': 1, '5': 1, 'K': 1, '8': 1, '3': 1}
# {'4': 2, 'T': 2, 'A': 1}
# {'9': 2, '8': 1, 'J': 1, 'Q': 1}
# {'5': 2, 'T': 1, 'Q': 1, '9': 1}
# {'3': 1, 'A': 1, 'K': 1, '7': 1, 'T': 1}
# {'9': 3, '4': 1, '3': 1}
# {'Q': 1, '4': 1, '3': 1, 'J': 1, 'A': 1}
# {'3': 1, '4': 1, 'K': 2, 'J': 1}
# {'8': 2, '4': 1, '9': 2}
# {'2': 3, '5': 2}
# {'7': 1, 'T': 1, '9': 1, 'K': 1, '6': 1}
# {'3': 2, '7': 1, 'J': 1, '9': 1}
# {'9': 4, '5': 1}
# {'J': 1, 'K': 2, '9': 2}
# {'5': 3, 'T': 2}
# {'3': 2, '9': 2, 'T': 1}
# {'J': 2, 'K': 3}
# {'K': 2, 'J': 2, 'T': 1}
# {'9': 1, 'K': 1, 'J': 1, '5': 2}
# {'5': 1, '9': 2, '6': 1, 'J': 1}
# {'9': 1, '2': 2, '7': 1, '3': 1}
# {'6': 2, 'T': 1, 'Q': 1, '8': 1}
# {'T': 1, '3': 1, '6': 1, 'K': 1, '5': 1}
# {'K': 2, '2': 1, '6': 2}
# {'5': 2, '6': 1, '2': 1, 'J': 1}
# {'4': 2, '3': 2, '9': 1}
# {'5': 4, '8': 1}
# {'9': 1, '6': 4}
# {'4': 1, '9': 1, '3': 1, '8': 1, 'T': 1}
# {'2': 1, 'Q': 3, '8': 1}
# {'8': 3, '7': 1, 'T': 1}
# {'K': 1, 'T': 1, '9': 1, '2': 1, 'Q': 1}
# {'6': 3, 'K': 1, '7': 1}
# {'6': 3, '7': 2}
# {'Q': 2, '5': 1, '2': 1, '4': 1}
# {'5': 2, '8': 2, '9': 1}
# {'4': 3, 'J': 1, '5': 1}
# {'6': 1, 'Q': 2, '8': 1, '2': 1}
# {'6': 2, 'Q': 1, 'J': 1, '3': 1}
# {'8': 1, '3': 2, '9': 2}
# {'3': 2, '2': 3}
# {'T': 2, '4': 1, '8': 2}
# {'6': 2, '2': 2, 'J': 1}
# {'5': 1, '3': 3, '2': 1}
# {'J': 2, '7': 3}
# {'5': 3, '9': 1, '4': 1}
# {'K': 2, 'J': 1, '4': 1, '8': 1}
# {'9': 1, '6': 1, 'A': 1, 'Q': 1, 'K': 1}
# {'Q': 1, 'J': 1, 'T': 1, '4': 1, '5': 1}
# {'K': 1, '3': 1, '8': 1, '2': 1, '6': 1}
# {'4': 4, '7': 1}
# {'4': 1, 'T': 1, '8': 1, '7': 2}
# {'8': 2, '3': 3}
# {'Q': 3, 'J': 1, '8': 1}
# {'3': 2, '6': 3}
# {'6': 2, 'Q': 2, '5': 1}
# {'A': 1, '4': 2, 'Q': 1, '9': 1}
# {'4': 1, '7': 1, 'K': 3}
# {'2': 3, '3': 1, 'J': 1}
# {'6': 1, '7': 1, 'J': 1, 'Q': 2}
# {'K': 1, '4': 1, '3': 1, 'J': 1, '7': 1}
# {'Q': 4, 'J': 1}
# {'3': 1, '2': 1, 'T': 1, '6': 1, '5': 1}
# {'4': 2, '6': 2, 'T': 1}
# {'T': 1, '3': 1, 'A': 1, '2': 1, '9': 1}
# {'7': 1, '5': 2, '6': 2}
# {'K': 1, 'Q': 2, '2': 1, 'T': 1}
# {'A': 1, 'J': 1, 'T': 2, '4': 1}
# {'Q': 2, 'K': 1, '4': 2}
# {'6': 2, 'J': 3}
# {'2': 1, '8': 3, '7': 1}
# {'3': 2, 'T': 1, 'K': 1, '4': 1}
# {'7': 2, 'J': 2, '2': 1}
# {'5': 2, '6': 2, 'J': 1}
# {'3': 3, 'A': 1, '5': 1}
# {'A': 2, '2': 1, '6': 2}
# {'6': 2, '2': 1, '9': 1, 'T': 1}
# {'3': 1, 'T': 1, 'Q': 1, '4': 1, '6': 1}
# {'J': 2, '8': 3}
# {'K': 3, 'J': 1, '4': 1}
# {'J': 1, '5': 1, 'T': 1, '4': 1, 'A': 1}
# {'4': 2, 'T': 2, '7': 1}
# {'4': 1, '7': 1, '3': 1, 'A': 1, '8': 1}
# {'A': 3, 'T': 2}
# {'4': 1, 'Q': 1, '3': 1, '8': 1, '5': 1}
# {'K': 2, '6': 2, '5': 1}
# {'3': 1, '9': 1, '8': 1, 'K': 1, '4': 1}
# {'6': 1, '5': 1, 'J': 1, 'T': 1, '7': 1}
# {'8': 1, 'A': 1, '6': 1, 'J': 1, '9': 1}
# {'Q': 2, 'A': 1, '5': 1, 'J': 1}
# {'Q': 1, '4': 1, '5': 1, 'K': 1, 'A': 1}
# {'A': 3, '6': 2}
# {'4': 2, '9': 2, 'Q': 1}
# {'K': 1, '9': 2, '7': 1, '2': 1}
# {'K': 4, 'T': 1}
# {'5': 1, 'J': 1, 'Q': 1, '2': 2}
# {'K': 2, '7': 2, '8': 1}
# {'T': 3, '8': 1, 'J': 1}
# {'2': 1, '6': 1, '5': 1, 'K': 1, 'A': 1}
# {'K': 4, '7': 1}
# {'6': 2, '2': 1, '3': 1, 'K': 1}
# {'6': 1, '5': 1, 'J': 1, '2': 1, 'K': 1}
# {'2': 3, '6': 1, '3': 1}
# {'4': 3, 'Q': 1, '7': 1}
# {'2': 1, '3': 3, '8': 1}
# {'K': 1, 'Q': 1, '9': 1, '4': 1, '8': 1}
# {'9': 1, '5': 2, '2': 1, 'J': 1}
# {'7': 1, '5': 1, 'J': 1, 'A': 1, '6': 1}
# {'3': 3, 'J': 2}
# {'2': 2, '8': 2, '4': 1}
# {'2': 1, 'A': 1, '8': 1, 'J': 1, 'K': 1}
# {'2': 2, '8': 2, '6': 1}
# {'8': 4, '3': 1}
# {'A': 1, '9': 1, '5': 2, 'Q': 1}
# {'5': 1, '4': 1, 'T': 1, '8': 1, '6': 1}
# {'5': 3, '4': 1, '7': 1}
# {'5': 1, 'T': 1, 'K': 1, '7': 1, 'Q': 1}
# {'4': 1, 'Q': 1, '3': 1, '5': 1, 'K': 1}
# {'3': 4, '5': 1}
# {'9': 1, '6': 1, 'A': 1, '8': 1, '5': 1}
# {'Q': 3, '6': 1, 'A': 1}
# {'K': 2, '5': 2, 'J': 1}
# {'9': 1, '7': 1, 'Q': 1, 'K': 1, '2': 1}
# {'K': 1, '6': 1, '2': 2, '9': 1}
# {'4': 2, 'T': 2, '8': 1}
# {'Q': 1, '6': 1, '7': 1, 'A': 1, 'J': 1}
# {'2': 3, 'T': 2}
# {'2': 2, 'Q': 1, 'J': 1, '4': 1}
# {'A': 1, '8': 2, 'T': 2}
# {'A': 1, '7': 1, '4': 1, 'Q': 1, '2': 1}
# {'7': 3, 'T': 2}
# {'7': 2, '4': 1, 'J': 1, 'T': 1}
# {'6': 1, 'A': 1, '8': 1, '4': 1, '5': 1}
# {'8': 1, 'J': 1, 'Q': 2, '5': 1}
# {'5': 3, '6': 1, '4': 1}
# {'6': 1, '8': 3, '7': 1}
# {'5': 1, 'J': 2, '2': 1, '7': 1}
# {'K': 1, '8': 2, 'J': 1, '6': 1}
# {'3': 2, 'A': 3}
# {'3': 1, 'J': 1, '7': 3}
# {'3': 1, '6': 3, 'K': 1}
# {'5': 1, 'Q': 1, 'A': 1, '9': 1, '8': 1}
# {'Q': 1, 'J': 1, '2': 2, '7': 1}
# {'4': 1, '5': 4}
# {'3': 3, 'T': 2}
# {'4': 3, '8': 1, 'T': 1}
# {'A': 3, '9': 2}
# {'7': 1, '6': 2, 'J': 1, 'A': 1}
# {'6': 1, 'T': 2, '4': 1, '8': 1}
# {'K': 2, 'T': 1, '7': 1, 'J': 1}
# {'7': 2, '2': 2, 'T': 1}
# {'8': 1, 'Q': 1, '7': 2, 'A': 1}
# {'Q': 1, '8': 2, '4': 2}
# {'T': 1, '3': 1, 'J': 2, '9': 1}
# {'8': 3, 'Q': 2}
# {'A': 3, '8': 1, '4': 1}
# {'7': 1, 'Q': 2, '2': 1, '6': 1}
# {'3': 2, '5': 1, '7': 2}
# {'T': 1, 'K': 3, '3': 1}
# {'T': 2, '7': 1, '6': 1, '4': 1}
# {'A': 2, 'T': 1, '9': 1, '8': 1}
# {'A': 3, '6': 1, '5': 1}
# {'5': 1, '7': 1, 'T': 1, '6': 1, '3': 1}
# {'6': 2, '2': 3}
# {'6': 4, '3': 1}
# {'J': 1, 'K': 2, 'Q': 2}
# {'6': 1, 'T': 1, '5': 1, 'A': 1, 'Q': 1}
# {'5': 3, '8': 2}
# {'3': 2, 'K': 1, 'A': 1, '7': 1}
# {'4': 3, '8': 2}
# {'A': 2, '9': 1, '5': 1, '8': 1}
# {'4': 1, 'Q': 1, '2': 1, '6': 1, 'A': 1}
# {'5': 1, '7': 2, 'A': 1, 'J': 1}
# {'8': 2, '4': 2, 'J': 1}
# {'6': 1, '3': 2, 'T': 1, 'J': 1}
# {'2': 4, '9': 1}
# {'Q': 2, '2': 3}
# {'J': 1, 'A': 3, 'Q': 1}
# {'T': 3, '6': 1, 'J': 1}
# {'Q': 1, '3': 1, 'K': 1, 'A': 1, 'J': 1}
# {'6': 3, 'T': 2}
# {'K': 1, '2': 1, '8': 1, 'Q': 2}
# {'K': 3, '4': 1, '6': 1}
# {'T': 1, '2': 4}
# {'8': 3, 'A': 1, '3': 1}
# {'J': 3, '7': 1, '3': 1}
# {'A': 1, 'J': 1, 'K': 1, '2': 1, '6': 1}
# {'7': 1, '2': 1, 'A': 1, '3': 1, '4': 1}
# {'T': 1, 'K': 2, '9': 1, 'Q': 1}
# {'3': 3, 'A': 2}
# {'8': 2, 'T': 2, '2': 1}
# {'8': 3, 'A': 1, '5': 1}
# {'5': 2, 'A': 1, '3': 1, '6': 1}
# {'8': 2, 'J': 1, 'K': 2}
# {'5': 3, '2': 1, '3': 1}
# {'K': 4, '2': 1}
# {'A': 2, '6': 1, '8': 2}
# {'6': 2, '2': 1, 'T': 1, 'Q': 1}
# {'A': 3, '2': 1, '4': 1}
# {'9': 4, 'K': 1}
# {'4': 2, 'J': 1, '8': 1, 'T': 1}
# {'6': 1, '7': 3, '8': 1}
# {'K': 2, '3': 2, 'Q': 1}
# {'Q': 2, '4': 2, 'J': 1}
# {'T': 1, 'K': 1, '7': 2, '8': 1}
# {'A': 2, '7': 1, '8': 1, '6': 1}
# {'Q': 3, 'J': 1, 'A': 1}
# {'J': 1, '2': 2, 'A': 1, '5': 1}
# {'9': 1, '6': 1, '5': 1, 'T': 2}
# {'5': 2, '9': 1, '8': 1, 'J': 1}
# {'K': 3, '8': 1, 'J': 1}
# {'K': 2, '5': 1, 'J': 1, '6': 1}
# {'Q': 2, 'J': 1, '2': 2}
# {'6': 1, '8': 1, '5': 1, 'Q': 1, 'A': 1}
# {'9': 4, 'J': 1}
# {'A': 1, '9': 2, '3': 2}
# {'9': 1, '5': 1, '3': 1, 'T': 1, '4': 1}
# {'3': 4, '7': 1}
# {'8': 2, 'J': 2, 'T': 1}
# {'4': 1, '2': 1, 'K': 1, '3': 1, '9': 1}
# {'Q': 2, '4': 1, '3': 1, '2': 1}
# {'K': 2, '2': 2, '4': 1}
# {'4': 3, 'A': 1, '2': 1}
# {'3': 2, 'J': 1, 'K': 2}
# {'6': 1, 'J': 1, 'T': 2, 'Q': 1}
# {'5': 1, 'K': 1, '9': 1, 'J': 1, '7': 1}
# {'7': 3, 'A': 1, '9': 1}
# {'6': 2, '8': 3}
# {'J': 1, 'Q': 1, '3': 1, '5': 2}
# {'T': 1, 'K': 1, '4': 1, '5': 1, '6': 1}
# {'9': 2, '3': 2, '7': 1}
# {'4': 2, '9': 2, 'J': 1}
# {'5': 1, '7': 4}
# {'6': 3, 'K': 2}
# {'T': 1, '3': 3, 'J': 1}
# {'4': 1, '6': 2, 'A': 2}
# {'5': 1, 'J': 2, '8': 1, 'Q': 1}
# {'A': 1, 'Q': 2, 'T': 2}
# {'3': 3, '5': 2}
# {'3': 3, 'T': 1, 'Q': 1}
# {'8': 3, 'J': 1, '5': 1}
# {'K': 3, 'J': 1, 'Q': 1}
# {'3': 1, '4': 1, 'J': 1, '9': 1, '7': 1}
# {'K': 1, '9': 3, '3': 1}
# {'Q': 4, '9': 1}
# {'4': 1, 'K': 1, '9': 1, 'A': 1, 'Q': 1}
# {'7': 1, 'K': 2, 'J': 1, '9': 1}
# {'9': 3, '4': 2}
# {'T': 2, '3': 1, 'Q': 1, '8': 1}
# {'T': 1, '2': 1, 'Q': 1, 'A': 1, '9': 1}
# {'J': 2, '5': 2, 'T': 1}
# {'J': 1, '6': 1, 'K': 1, 'A': 1, 'Q': 1}
# {'4': 1, '7': 1, '3': 1, '5': 1, 'Q': 1}
# {'3': 1, 'J': 1, '5': 1, '4': 1, '7': 1}
# {'6': 2, '4': 3}
# {'7': 2, 'J': 1, '9': 1, '4': 1}
# {'6': 3, '2': 1, 'Q': 1}
# {'J': 1, '3': 2, '8': 1, '2': 1}
# {'9': 1, '6': 1, 'Q': 1, 'K': 1, '3': 1}
# {'A': 2, '4': 2, 'J': 1}
# {'J': 1, '7': 2, 'K': 2}
# {'K': 1, '8': 1, '3': 1, '5': 1, '4': 1}
# {'J': 1, 'A': 1, 'T': 1, 'Q': 1, '9': 1}
# {'2': 2, '8': 1, '7': 1, '3': 1}
# {'7': 3, '2': 1, '9': 1}
# {'4': 1, 'J': 1, '2': 1, '5': 2}
# {'7': 4, 'K': 1}
# {'J': 3, 'Q': 1, '5': 1}
# {'8': 1, '2': 1, 'A': 1, '4': 1, '7': 1}
# {'8': 3, 'T': 1, '4': 1}
# {'2': 3, 'K': 2}
# {'T': 1, '3': 1, '5': 1, 'Q': 1, '8': 1}
# {'9': 1, '4': 1, '2': 1, '3': 1, '8': 1}
# {'5': 1, 'K': 1, '2': 2, '4': 1}
# {'5': 2, 'Q': 1, 'J': 1, 'A': 1}
# {'4': 1, 'T': 1, '6': 1, 'K': 1, 'A': 1}
# {'7': 1, '4': 1, 'J': 1, '8': 1, 'A': 1}
# {'4': 2, 'J': 2, 'K': 1}
# {'A': 1, '7': 1, '6': 1, 'Q': 2}
# {'9': 1, '8': 3, 'A': 1}
# {'8': 1, '6': 1, 'J': 1, '3': 1, '2': 1}
# {'7': 1, 'Q': 1, 'K': 1, '3': 1, '2': 1}
# {'7': 1, 'T': 4}
# {'K': 3, '2': 1, '7': 1}
# {'8': 1, 'A': 1, '3': 1, '6': 2}
# {'8': 1, '3': 3, 'J': 1}
# {'5': 2, '2': 1, 'Q': 2}
# {'9': 2, '5': 1, '2': 1, '6': 1}
# {'A': 2, 'K': 1, '3': 2}
# {'A': 1, '3': 1, '6': 1, '8': 1, 'K': 1}
# {'Q': 3, 'A': 1, '5': 1}
# {'5': 1, '9': 3, 'J': 1}
# {'K': 3, '9': 1, 'J': 1}
# {'6': 1, 'Q': 2, '2': 2}
# {'A': 2, 'K': 2, '7': 1}
# {'5': 3, 'Q': 1, '3': 1}
# {'2': 2, 'A': 2, '6': 1}
# {'3': 2, '8': 2, '5': 1}
# {'J': 1, 'T': 1, 'A': 1, '8': 1, '2': 1}
# {'8': 2, 'J': 1, '6': 2}
# {'J': 1, '9': 3, 'K': 1}
# {'Q': 1, 'J': 1, '3': 1, '5': 1, 'T': 1}
# {'A': 3, 'Q': 1, '7': 1}
# {'7': 3, 'K': 1, 'J': 1}
# {'J': 1, '6': 1, '2': 2, '8': 1}
# {'8': 1, 'K': 1, '2': 1, 'T': 1, '3': 1}
# {'4': 1, '3': 1, 'Q': 1, '8': 1, '2': 1}
# {'6': 3, 'T': 1, 'K': 1}
# {'7': 3, 'A': 2}
# {'A': 3, '9': 1, '8': 1}
# {'Q': 4, '7': 1}
# {'9': 3, 'J': 2}
# {'4': 3, 'T': 1, 'J': 1}
# {'A': 1, '7': 1, '2': 1, '6': 1, '3': 1}
# {'7': 2, '4': 2, '9': 1}
# {'2': 2, 'K': 3}
# {'8': 1, 'K': 1, '6': 1, 'J': 1, 'Q': 1}
# {'6': 1, 'T': 1, 'J': 1, '5': 1, '8': 1}
# {'7': 1, '2': 4}
# {'9': 2, 'A': 2, '7': 1}
# {'3': 1, '7': 1, 'T': 2, '6': 1}
# {'8': 4, '2': 1}
# {'6': 2, '5': 3}
# {'5': 4, 'J': 1}
# {'7': 3, 'A': 1, '2': 1}
# {'3': 2, 'Q': 2, '5': 1}
# {'T': 2, 'Q': 1, '4': 2}
# {'3': 1, 'T': 3, '8': 1}
# {'4': 1, '2': 1, '8': 1, 'T': 1, '3': 1}
# {'A': 1, 'K': 1, '8': 1, '9': 1, '7': 1}
# {'7': 1, 'Q': 3, 'J': 1}
# {'9': 1, 'A': 1, 'K': 1, '6': 1, '2': 1}
# {'9': 1, '6': 3, '4': 1}
# {'J': 2, '5': 1, '2': 2}
# {'9': 2, 'J': 1, '7': 1, 'A': 1}
# {'Q': 2, 'K': 1, '7': 2}
# {'Q': 1, '7': 1, '2': 1, 'T': 1, '4': 1}
# {'2': 2, '6': 3}
# {'9': 1, 'K': 2, '3': 1, '2': 1}
# {'4': 1, '5': 1, 'Q': 1, 'J': 1, '6': 1}
# {'4': 1, '5': 1, 'Q': 1, 'K': 1, 'J': 1}
# {'K': 2, '2': 1, '4': 1, '8': 1}
# {'A': 4, '4': 1}
# {'2': 2, 'T': 1, 'Q': 2}
# {'9': 3, '2': 1, 'J': 1}
# {'4': 1, '7': 4}
# {'K': 1, 'J': 2, 'T': 1, '5': 1}
# {'5': 1, 'T': 1, 'A': 1, '6': 1, '4': 1}
# {'5': 3, 'A': 2}
# {'7': 1, 'Q': 1, 'T': 1, '3': 1, '5': 1}
# {'8': 1, 'J': 2, 'T': 1, '6': 1}
# {'K': 2, '4': 2, '5': 1}
# {'4': 3, 'Q': 1, '9': 1}
# {'K': 1, 'T': 1, '4': 1, '2': 1, '7': 1}
# {'T': 2, 'J': 1, '3': 2}
# {'T': 1, '7': 2, '5': 1, '8': 1}
# {'A': 1, '9': 1, '3': 1, '4': 1, '7': 1}
# {'9': 1, '4': 1, '2': 2, 'J': 1}
# {'Q': 2, '9': 2, 'J': 1}
# {'J': 1, '7': 1, '4': 2, '5': 1}
# {'7': 1, 'A': 1, '5': 1, '4': 1, 'J': 1}
# {'Q': 1, 'K': 2, '4': 2}
# {'7': 1, 'K': 1, 'J': 1, '9': 2}
# {'7': 1, '8': 3, 'Q': 1}
# {'4': 4, 'J': 1}
# {'3': 1, '6': 1, '5': 1, 'K': 1, '8': 1}
# {'8': 3, '9': 1, '3': 1}
# {'2': 2, 'T': 1, 'Q': 1, 'J': 1}
# {'2': 2, '8': 1, 'K': 1, 'J': 1}
# {'8': 2, '4': 1, 'A': 1, 'T': 1}
# {'7': 2, '2': 1, '9': 1, '6': 1}
# {'3': 1, 'K': 3, 'A': 1}
# {'5': 3, '9': 2}
# {'7': 1, 'J': 1, 'K': 1, '3': 1, '5': 1}
# {'J': 1, '8': 3, 'Q': 1}
# {'Q': 1, 'A': 1, '5': 1, '4': 1, '3': 1}
# {'8': 2, '6': 2, 'A': 1}
# {'T': 1, '4': 2, 'A': 2}
# {'Q': 4, 'A': 1}
# {'J': 1, '8': 2, 'T': 2}
# {'7': 2, 'J': 1, 'T': 1, '6': 1}
# {'J': 1, '5': 1, '7': 2, '9': 1}
# {'8': 1, '6': 1, 'A': 2, '3': 1}
# {'T': 1, 'A': 3, '3': 1}
# {'5': 2, 'J': 1, '6': 1, 'K': 1}
# {'7': 1, '8': 1, '2': 1, '5': 1, '3': 1}
# {'T': 3, 'K': 1, '3': 1}
# {'Q': 1, '8': 1, '5': 1, '9': 2}
# {'Q': 1, 'T': 4}
# {'7': 2, 'K': 2, '3': 1}
# {'T': 1, 'K': 3, 'J': 1}
# {'7': 1, 'Q': 1, '5': 2, '4': 1}
# {'K': 3, 'Q': 2}
# {'7': 2, '8': 1, '6': 2}
# {'4': 2, '3': 1, '5': 2}
# {'J': 1, '6': 2, '9': 2}
# {'9': 1, '8': 1, '5': 1, 'A': 1, '3': 1}
# {'J': 2, 'Q': 3}
# {'5': 1, 'J': 2, '9': 1, 'T': 1}
# {'6': 1, 'T': 1, '4': 2, 'A': 1}
# {'K': 1, 'A': 1, '9': 1, 'J': 1, '2': 1}
# {'2': 3, '3': 1, '9': 1}
# {'3': 2, 'Q': 1, 'K': 1, '9': 1}
# {'2': 2, 'T': 3}
# {'2': 2, '9': 3}
# {'T': 1, 'K': 1, '7': 1, 'J': 2}
# {'7': 2, '2': 1, '8': 1, 'A': 1}
# {'J': 2, '4': 2, '2': 1}
# {'A': 2, 'J': 1, '5': 1, '3': 1}
# {'J': 1, 'A': 2, '4': 1, '5': 1}
# {'7': 2, '2': 2, '8': 1}
# {'7': 4, 'T': 1}
# {'4': 1, '3': 3, '5': 1}
# {'9': 2, '3': 2, '2': 1}
# {'7': 1, 'A': 4}
# {'8': 4, 'K': 1}
# {'4': 2, '7': 2, 'J': 1}
# {'6': 1, '8': 1, '4': 1, 'Q': 1, 'J': 1}
# {'7': 1, '3': 1, '4': 1, '9': 1, '5': 1}
# {'2': 2, '5': 2, 'J': 1}
# {'7': 1, 'Q': 1, 'K': 1, 'T': 1, '2': 1}
# {'A': 3, '4': 1, '6': 1}
# {'2': 1, 'T': 3, '8': 1}
# {'7': 2, 'J': 1, '4': 1, '6': 1}
# {'3': 2, 'J': 1, '2': 1, '4': 1}
# {'Q': 4, '3': 1}
# {'A': 3, 'J': 2}
# {'8': 1, 'K': 1, '5': 2, 'Q': 1}
# {'K': 1, '9': 1, 'T': 2, 'J': 1}
# {'3': 2, 'Q': 2, '7': 1}
# {'T': 1, '7': 3, '9': 1}
# {'6': 1, '9': 3, '8': 1}
# {'J': 1, '6': 3, 'T': 1}
# {'J': 1, '2': 2, '3': 2}
# {'9': 3, '4': 1, '6': 1}
# {'8': 3, '9': 1, 'Q': 1}
# {'K': 1, '9': 1, '7': 1, 'A': 1, '6': 1}
# {'7': 1, '3': 2, 'T': 1, 'J': 1}
# {'6': 3, '3': 1, 'J': 1}
# {'5': 1, '4': 1, 'Q': 2, 'T': 1}
# {'4': 2, 'A': 3}
# {'4': 2, '3': 2, 'A': 1}
# {'J': 5}
# {'J': 1, 'K': 1, '2': 1, 'T': 2}
# {'2': 1, '7': 2, '4': 1, 'A': 1}
# {'K': 2, '8': 1, 'J': 1, 'A': 1}
# {'A': 2, 'J': 1, '3': 1, '8': 1}
# {'3': 1, 'K': 3, 'J': 1}
# {'6': 2, '9': 2, '3': 1}
# {'4': 2, '8': 1, 'J': 1, '7': 1}
# {'7': 2, 'K': 2, 'A': 1}
# {'3': 2, '2': 1, '4': 2}
# {'5': 2, 'A': 1, '4': 1, '3': 1}
# {'8': 2, '7': 1, 'K': 1, 'A': 1}
# {'J': 1, '2': 1, '4': 2, '8': 1}
# {'K': 2, '3': 1, '5': 2}
# {'K': 1, '8': 1, 'Q': 1, '2': 1, 'A': 1}
# {'K': 2, '3': 1, 'Q': 1, '4': 1}
# {'7': 3, 'J': 1, 'A': 1}
# {'8': 1, '4': 1, 'T': 2, '5': 1}
# {'7': 1, '8': 1, '9': 1, '3': 1, 'T': 1}
# {'2': 2, 'A': 3}
# {'Q': 2, 'K': 2, '6': 1}
# {'T': 1, '6': 1, 'A': 1, '4': 1, '8': 1}
# {'T': 2, '2': 2, '9': 1}
# {'K': 1, 'A': 1, '5': 1, '3': 1, 'Q': 1}
# {'6': 1, '8': 1, 'J': 1, '5': 1, 'K': 1}
# {'6': 2, '4': 1, '2': 1, '5': 1}
# {'3': 2, 'T': 2, '5': 1}
# {'2': 2, '9': 2, 'J': 1}
# {'A': 1, '3': 1, 'K': 1, '8': 1, 'J': 1}
# {'Q': 1, 'K': 1, '9': 2, 'J': 1}
# {'4': 2, 'A': 2, 'Q': 1}
# {'K': 4, '8': 1}
# {'A': 3, '2': 1, '8': 1}
# {'4': 1, '2': 2, '7': 2}
# {'T': 1, '2': 3, 'A': 1}
# {'K': 1, '6': 1, 'Q': 1, '3': 1, '7': 1}
# {'Q': 1, '5': 1, 'K': 1, '6': 1, 'A': 1}
# {'8': 2, 'Q': 2, 'J': 1}
# {'8': 2, '3': 1, '2': 1, 'J': 1}
# {'Q': 1, '3': 1, '8': 2, 'T': 1}
# {'9': 1, '5': 3, 'J': 1}
# {'7': 1, 'K': 1, 'T': 2, '9': 1}
# {'K': 3, 'A': 2}
# {'T': 4, 'K': 1}
# {'4': 2, 'T': 1, 'J': 1, '2': 1}
# {'6': 2, 'K': 3}
# {'5': 2, 'A': 2, 'T': 1}
# {'A': 2, 'J': 1, '2': 2}
# {'6': 1, '3': 3, 'Q': 1}
# {'Q': 4, '4': 1}
# {'4': 2, 'A': 1, 'Q': 1, '2': 1}
# {'3': 2, '5': 3}
# {'Q': 1, '9': 1, 'A': 1, '2': 1, '3': 1}
# {'3': 3, 'Q': 1, '4': 1}
# {'9': 3, 'Q': 1, '7': 1}
# {'3': 1, 'K': 3, 'Q': 1}
# {'J': 1, 'K': 2, '5': 1, '4': 1}
# {'9': 3, '6': 2}
# {'2': 1, 'T': 1, '3': 1, '7': 1, '4': 1}
# {'4': 1, 'Q': 2, 'J': 1, 'A': 1}
# {'J': 1, 'Q': 1, '6': 1, '4': 1, 'K': 1}
# {'4': 2, '6': 2, 'Q': 1}
# {'J': 1, '9': 1, '2': 2, '5': 1}
# {'8': 3, 'Q': 1, '3': 1}
# {'K': 1, '4': 1, 'J': 1, '5': 2}
# {'5': 1, 'J': 1, 'T': 1, '7': 1, '3': 1}
# {'K': 2, '6': 1, 'J': 1, '4': 1}
# {'A': 4, '8': 1}
# {'7': 2, '9': 2, '3': 1}
# {'8': 1, '7': 3, 'J': 1}
# {'J': 1, '4': 3, '8': 1}
# {'A': 1, '4': 2, '3': 1, 'J': 1}
# {'T': 2, 'Q': 1, 'J': 1, '7': 1}
# {'6': 1, '3': 4}
# {'2': 4, '6': 1}
# {'4': 2, '7': 1, 'Q': 2}
# {'Q': 1, '2': 3, 'K': 1}
# {'K': 3, '5': 1, '2': 1}
# {'Q': 2, '6': 1, '2': 1, 'T': 1}
# {'J': 1, '6': 4}
# {'A': 4, 'Q': 1}
# {'6': 4, '5': 1}
# {'7': 2, '8': 2, 'K': 1}
# {'8': 1, 'A': 1, '3': 1, 'T': 1, '9': 1}
# {'A': 2, '3': 1, '9': 1, '2': 1}
# {'T': 2, '5': 1, '9': 1, '3': 1}
# {'Q': 2, '2': 1, 'K': 2}
# {'7': 1, '6': 1, '5': 1, 'K': 1, 'A': 1}
# {'Q': 3, '5': 1, '7': 1}
# {'4': 2, 'K': 2, 'T': 1}
# {'6': 2, '2': 1, '4': 1, '3': 1}
# {'8': 1, '9': 1, '5': 1, 'T': 1, 'J': 1}
# {'Q': 1, 'T': 1, '3': 1, '4': 1, '5': 1}
# {'3': 3, '2': 1, 'T': 1}
# {'2': 1, 'T': 1, '5': 1, 'J': 1, '9': 1}
# {'2': 1, '4': 1, 'J': 1, '9': 1, 'K': 1}
# {'5': 3, '7': 1, 'A': 1}
# {'J': 3, '3': 1, '5': 1}
# {'7': 1, '5': 4}
# {'6': 1, '5': 1, '9': 1, 'T': 1, '2': 1}
# {'T': 2, 'Q': 1, '5': 1, 'J': 1}
# {'7': 1, 'T': 1, '4': 1, '8': 1, 'A': 1}
# {'2': 2, '3': 3}
# {'K': 3, 'J': 1, '6': 1}
# {'4': 1, '3': 3, 'J': 1}
# {'K': 3, '5': 2}
# {'A': 3, '8': 1, 'J': 1}
# {'6': 1, '8': 2, 'J': 1, '9': 1}
# {'K': 1, 'J': 1, 'Q': 1, 'T': 1, '9': 1}
# {'9': 3, '8': 2}
# {'Q': 2, '3': 1, 'T': 1, '4': 1}
# {'7': 1, '6': 1, '4': 1, 'Q': 2}
# {'7': 3, '2': 1, 'Q': 1}
# {'6': 2, 'K': 1, 'T': 1, '5': 1}
# {'3': 2, '8': 2, 'Q': 1}
# {'J': 1, 'K': 1, '6': 1, '7': 2}
# {'T': 4, '4': 1}
# {'7': 1, '6': 1, 'K': 1, '8': 1, '2': 1}
# {'J': 1, 'A': 4}
# {'3': 2, 'J': 2, '5': 1}
# {'8': 1, 'T': 3, 'K': 1}
# {'8': 1, 'T': 2, '7': 1, '4': 1}
# {'8': 4, 'J': 1}
# {'7': 1, '4': 1, '9': 1, '3': 1, '8': 1}
# {'3': 1, 'T': 1, 'K': 1, '7': 1, '4': 1}
# {'T': 1, '9': 1, '8': 1, 'K': 1, '5': 1}
# {'9': 3, 'A': 1, '6': 1}
# {'2': 1, '4': 1, 'A': 1, '6': 1, 'K': 1}
# {'4': 2, '3': 1, 'A': 1, '2': 1}
# {'T': 2, '9': 2, 'J': 1}
# {'J': 1, '8': 1, '3': 1, '7': 1, 'Q': 1}
# {'4': 4, '6': 1}
# {'8': 1, '2': 1, 'A': 2, '5': 1}
# {'A': 3, 'T': 1, 'J': 1}
# {'8': 2, '3': 1, '9': 2}
# {'8': 2, 'T': 2, 'Q': 1}
# {'6': 1, '9': 1, '4': 1, '8': 1, '2': 1}
# {'3': 2, '6': 2, 'J': 1}
# {'4': 1, '5': 1, '8': 1, 'T': 1, '7': 1}
# {'4': 1, 'Q': 2, '2': 1, '9': 1}
# {'K': 4, '4': 1}
# {'4': 1, 'K': 1, '7': 1, '5': 1, '6': 1}
# {'8': 2, 'J': 3}
# {'T': 4, '9': 1}
# {'8': 3, 'J': 1, '2': 1}
# {'4': 2, '2': 3}
# {'Q': 3, 'K': 2}
# {'4': 1, 'J': 1, '2': 1, 'Q': 1, '7': 1}
# {'5': 1, '7': 1, '9': 1, '2': 2}
# {'4': 4, 'A': 1}
# {'3': 1, '5': 3, '9': 1}
# {'T': 2, '8': 1, 'Q': 2}
# {'J': 1, 'Q': 1, '2': 1, '9': 1, 'K': 1}
# {'9': 4, 'A': 1}
# {'6': 1, '2': 2, 'T': 2}
# {'K': 1, '3': 1, '5': 1, '6': 1, '7': 1}
# {'7': 1, '2': 3, 'J': 1}
# {'8': 2, '7': 2, '4': 1}
# {'5': 3, 'J': 1, '6': 1}
# {'2': 1, '6': 2, '7': 1, '9': 1}
# {'5': 1, '7': 3, 'A': 1}
# {'4': 2, 'T': 1, '8': 1, '6': 1}
# {'7': 2, 'Q': 2, '2': 1}
# {'2': 1, '8': 1, 'Q': 1, 'J': 1, '3': 1}
# {'2': 1, '4': 1, '3': 1, 'K': 1, '7': 1}
# {'2': 1, '4': 1, 'J': 1, '9': 1, '7': 1}
# {'4': 1, 'Q': 1, 'K': 1, 'T': 1, '3': 1}
# {'A': 3, '8': 2}
# {'3': 2, '6': 1, 'A': 2}
# {'T': 2, '2': 1, '4': 1, 'J': 1}
# {'9': 1, '2': 1, 'A': 1, 'J': 1, '6': 1}
# {'J': 2, '6': 3}
# {'Q': 1, '7': 1, 'J': 1, '3': 1, '6': 1}
# {'Q': 1, '3': 1, '9': 1, '6': 1, '8': 1}
# {'8': 1, 'J': 2, '7': 1, 'K': 1}
# {'5': 1, 'J': 1, '9': 1, 'T': 1, '3': 1}
# {'2': 3, '9': 1, 'Q': 1}
# {'5': 2, '8': 2, 'J': 1}
# {'7': 3, '4': 1, 'T': 1}
# {'7': 1, '3': 1, '5': 1, 'A': 1, '6': 1}
# {'4': 4, '9': 1}
# {'4': 2, 'J': 1, '2': 1, '6': 1}
# {'5': 4, '2': 1}
# {'Q': 1, '4': 1, 'T': 2, '3': 1}
# {'K': 2, '8': 2, 'T': 1}
# {'6': 1, 'J': 2, 'T': 2}
# {'K': 1, 'T': 1, 'A': 1, '5': 1, '4': 1}
# {'K': 2, 'T': 2, '5': 1}
# {'A': 2, '8': 1, '5': 2}
# {'9': 1, '6': 2, 'J': 2}
# {'9': 1, 'K': 4}
# {'3': 3, '7': 2}
# {'K': 1, 'J': 2, '6': 2}
# {'2': 2, 'Q': 1, '8': 2}
# {'J': 4, '8': 1}
# {'T': 3, 'J': 2}
# {'A': 4, 'K': 1}
# {'J': 1, '6': 2, 'T': 2}
# {'Q': 1, '7': 2, 'J': 1, 'T': 1}
# {'8': 2, 'T': 1, '7': 1, '2': 1}
# {'8': 1, '6': 1, 'J': 1, '5': 2}
# {'8': 1, 'K': 3, '5': 1}
# {'K': 2, 'A': 1, 'T': 2}
# {'T': 1, '9': 2, '2': 1, 'J': 1}
# {'2': 2, '3': 1, '8': 1, 'J': 1}
# {'9': 4, '2': 1}
# {'8': 1, '2': 1, 'Q': 1, '5': 1, 'T': 1}
# {'2': 3, '9': 1, '7': 1}
# {'Q': 3, '5': 1, '8': 1}
# {'8': 2, 'A': 1, 'Q': 1, '5': 1}
# {'8': 1, '7': 1, 'J': 1, '2': 1, 'Q': 1}
# {'T': 1, '2': 1, 'A': 1, '3': 1, '5': 1}
# {'9': 1, 'T': 1, 'Q': 3}
# {'2': 1, 'K': 1, 'T': 1, '6': 1, '9': 1}
# {'5': 2, 'T': 1, '6': 2}
# {'J': 1, '3': 2, 'Q': 2}
# {'2': 2, 'T': 1, '6': 1, '5': 1}
# {'K': 1, 'T': 1, '2': 2, '8': 1}
# {'9': 2, 'T': 1, '2': 2}
# {'T': 1, 'A': 1, '6': 2, '9': 1}
# {'Q': 1, '3': 1, '5': 2, '8': 1}
# {'A': 3, 'Q': 1, 'K': 1}
# {'J': 3, '9': 2}
# {'Q': 2, '4': 2, '8': 1}
# {'T': 2, '6': 2, '4': 1}
# {'J': 3, '2': 1, '5': 1}
# {'6': 2, '7': 3}
# {'Q': 4, 'T': 1}
# {'3': 4, 'J': 1}
# {'Q': 3, '2': 2}
# {'8': 1, 'K': 1, '7': 1, '9': 1, 'T': 1}
# {'J': 1, '8': 1, '2': 2, 'A': 1}
# {'T': 4, '5': 1}
# {'4': 2, 'K': 1, 'Q': 1, '8': 1}
# {'A': 2, '7': 1, 'J': 2}
# {'4': 3, 'Q': 2}
# {'2': 1, 'J': 2, '6': 1, 'K': 1}
# {'7': 3, '9': 2}
# {'5': 3, '7': 2}
# {'Q': 2, 'K': 1, '6': 2}
# {'Q': 3, '5': 1, 'K': 1}
# {'8': 1, 'Q': 1, '5': 1, 'J': 1, '2': 1}
# {'T': 1, 'K': 1, 'J': 1, '2': 1, '7': 1}
# {'T': 3, '7': 1, '5': 1}
# {'2': 3, '7': 1, 'A': 1}
# {'4': 2, '5': 1, '7': 1, '8': 1}
# {'A': 1, 'Q': 1, 'K': 1, '9': 1, '7': 1}
# {'9': 1, '8': 1, 'T': 3}
# {'2': 1, '8': 2, '6': 1, 'T': 1}
# {'J': 1, 'A': 2, '6': 2}
# {'4': 2, '3': 3}
# {'A': 1, '3': 3, 'J': 1}
# {'Q': 1, '8': 1, '2': 1, 'T': 1, '6': 1}
# {'J': 1, '8': 1, '3': 2, 'Q': 1}
# {'4': 1, 'T': 1, '9': 1, '8': 1, 'J': 1}
# {'4': 3, '9': 2}
# {'Q': 3, '5': 2}
# {'3': 1, '7': 3, '4': 1}
# {'2': 1, '8': 1, 'Q': 1, 'K': 1, 'T': 1}
# {'3': 2, 'K': 1, '8': 2}
# {'J': 1, '3': 2, '8': 2}
# {'8': 1, '3': 1, '4': 3}
# {'7': 1, 'T': 3, 'A': 1}
# {'8': 1, '7': 4}
# {'K': 2, 'J': 1, 'T': 1, '5': 1}
# {'Q': 3, '2': 1, '7': 1}
# {'2': 3, '9': 2}
# {'9': 3, 'K': 1, 'A': 1}
# {'4': 4, '5': 1}
# {'J': 1, '6': 1, '8': 1, '9': 1, 'T': 1}
# {'8': 4, '6': 1}
# {'T': 3, 'A': 2}
# {'2': 2, '4': 2, '5': 1}
# {'5': 1, '4': 2, 'Q': 1, '2': 1}
# {'T': 3, '9': 1, '7': 1}
# {'Q': 1, 'J': 2, 'A': 2}
# {'2': 1, '3': 1, 'K': 1, '8': 1, 'Q': 1}
# {'A': 3, 'J': 1, '5': 1}
# {'5': 2, '9': 2, '8': 1}
# {'6': 1, 'T': 2, '5': 2}
# {'Q': 1, '6': 1, '8': 1, '9': 1, '2': 1}
# {'Q': 2, '6': 2, '7': 1}
# {'A': 1, '2': 3, '3': 1}
# {'6': 1, '9': 2, '8': 1, 'J': 1}
# {'9': 1, '4': 2, 'A': 1, '6': 1}
# {'7': 1, 'K': 1, '5': 1, '2': 1, '4': 1}
# {'4': 2, '9': 2, '8': 1}
# {'5': 2, 'Q': 1, '2': 1, '9': 1}
# {'8': 2, 'A': 1, '7': 2}
# {'A': 1, '7': 2, 'Q': 2}
# {'9': 1, '2': 1, '4': 3}
# {'5': 2, '8': 1, 'J': 1, '2': 1}
# {'7': 3, 'J': 1, 'T': 1}
# {'4': 1, '9': 2, '3': 1, 'K': 1}
# {'7': 1, 'A': 1, '3': 3}
# {'9': 2, 'T': 1, 'Q': 2}
# {'J': 1, '9': 1, '2': 1, 'K': 1, 'T': 1}
# {'9': 1, 'T': 1, 'J': 1, '6': 1, '7': 1}
# {'4': 3, '3': 2}
# {'9': 2, 'T': 3}
# {'6': 4, '2': 1}
# {'A': 3, 'K': 2}
# {'7': 1, 'A': 1, 'T': 1, 'J': 2}
# {'K': 1, '8': 1, '6': 2, 'J': 1}
# {'2': 4, '4': 1}
# {'A': 3, 'T': 1, 'Q': 1}
# {'6': 2, '4': 1, '3': 1, '7': 1}
# {'7': 4, '2': 1}
# {'6': 3, 'Q': 2}
# {'3': 2, '7': 3}
# {'A': 1, '8': 1, '6': 1, '2': 1, '4': 1}
# {'2': 2, '7': 2, '6': 1}
# {'2': 2, '9': 1, '5': 1, '4': 1}
# {'T': 2, 'K': 1, '4': 1, 'J': 1}
# [(3, '7227Q', '52'), (2, '67Q64', '732'), (6, '33Q33', '573'), (1, '58ATQ', '939'), (2, '93K53', '840'), (2, '55AJ8', '496'), (3, '6ATAT', '863'), (2, '26J77', '1'), (4, 'TTQAT', '381'), (5, '2J2J2', '322'), (2, '342Q2', '409'), (4, '3444Q', '864'), (4, '77J67', '31'), (2, '772QJ', '796'), (2, '5388J', '956'), (5, '7JJ7J', '88'), (6, '5Q555', '626'), (2, '77AK8', '588'), (6, 'J2222', '661'), (2, '36T93', '934'), (2, '5Q365', '343'), (5, 'K3K3K', '283'), (3, '5959A', '537'), (5, '44477', '560'), (2, '6AA5K', '208'), (3, '5J445', '262'), (5, '28228', '61'), (4, '646A6', '503'), (2, 'KK4Q8', '471'), (1, 'A426T', '500'), (2, 'AQ9JA', '643'), (1, 'J784T', '348'), (2, '22J48', '6'), (3, 'A5AJ5', '220'), (2, '62235', '545'), (4, '84JJJ', '206'), (4, '48464', '669'), (6, '44844', '637'), (1, 'Q8537', '969'), (2, '95663', '751'), (1, 'JTQK7', '305'), (5, '33TTT', '335'), (1, '4T925', '32'), (4, '9777Q', '738'), (3, '2QQ66', '971'), (3, 'TQQ9T', '657'), (1, '69437', '176'), (4, '2555J', '849'), (5, '55AAA', '26'), (3, '94TT4', '531'), (2, '89T66', '55'), (2, '387J8', '663'), (6, 'KKKKJ', '198'), (5, 'K4KK4', '870'), (4, '622J2', '330'), (1, '6283A', '337'), (4, 'JQQQ2', '349'), (5, '666AA', '706'), (2, '9794J', '966'), (4, '99A9T', '771'), (3, '53J53', '477'), (2, '7JT3J', '829'), (2, 'KK524', '765'), (5, 'Q4QQ4', '486'), (2, 'J7367', '519'), (2, 'KK4TJ', '937'), (1, 'Q4983', '168'), (4, '74A77', '997'), (3, 'Q2244', '464'), (3, '242J4', '625'), (1, 'J2839', '326'), (2, 'T927T', '773'), (3, '2Q992', '875'), (5, '77722', '467'), (1, '8K645', '959'), (2, 'AJTJ3', '650'), (1, '64Q35', '98'), (4, 'QQTQ4', '973'), (3, '24492', '438'), (1, 'T8AK7', '983'), (1, 'K439T', '924'), (3, '7AJ7J', '426'), (3, 'T88T5', '801'), (4, '9J939', '267'), (3, '7K557', '458'), (1, 'T9KQ3', '231'), (6, '34444', '720'), (5, '44TTT', '781'), (4, 'AA3A9', '177'), (5, '78878', '479'), (4, '4K474', '932'), (2, '3TT65', '634'), (5, '98898', '113'), (3, '26286', '702'), (3, '37736', '673'), (2, '9Q9K3', '103'), (3, '9TT92', '755'), (3, '8AAJ8', '845'), (6, '55A55', '356'), (6, 'K2222', '184'), (6, '7777Q', '950'), (1, '64392', '649'), (3, '36653', '891'), (5, '22AA2', '201'), (2, '55943', '367'), (3, 'AQA2Q', '178'), (1, '4T693', '806'), (2, '385J5', '429'), (2, '246Q6', '930'), (2, '32J2Q', '428'), (1, '59Q83', '128'), (2, '8684Q', '828'), (1, '482Q9', '668'), (1, '243QA', '250'), (4, 'JQTQQ', '656'), (3, '45645', '354'), (1, '7J648', '534'), (3, '44633', '638'), (2, 'A3283', '284'), (2, '38262', '830'), (1, 'QAT67', '976'), (2, '7662Q', '241'), (3, '266T2', '355'), (2, '3AA67', '958'), (6, 'JTTTT', '51'), (2, 'A3T22', '739'), (1, '6A45J', '978'), (3, '969JJ', '965'), (2, '69K98', '413'), (3, '8Q33Q', '239'), (3, '886QQ', '135'), (2, 'Q44JK', '525'), (6, 'TT6TT', '64'), (6, '77773', '451'), (3, '8AKK8', '172'), (3, 'QTQ2T', '872'), (4, 'QQTQ7', '642'), (5, '44666', '387'), (2, 'J4Q74', '225'), (1, '4J968', '542'), (2, 'Q6939', '831'), (2, '2773T', '420'), (6, '55565', '313'), (6, '76666', '9'), (3, '5J4J4', '212'), (3, 'TTJQJ', '601'), (1, '358K2', '725'), (2, 'JQ78Q', '597'), (3, '3K3TK', '685'), (6, 'QKQQQ', '261'), (3, '5Q59Q', '762'), (5, 'Q77QQ', '756'), (3, 'KK2J2', '728'), (4, 'TKKK5', '879'), (3, '9KQ9K', '785'), (1, 'Q83JK', '96'), (4, '39998', '256'), (4, 'TTJ3T', '852'), (6, '66866', '192'), (1, '2567T', '211'), (3, '76969', '20'), (6, 'KAKKK', '735'), (4, '9Q5QQ', '808'), (1, 'JQ87K', '67'), (4, 'J8887', '320'), (1, 'J9763', '36'), (3, 'A6464', '75'), (3, 'K5AA5', '996'), (4, 'TTJ7T', '890'), (5, '7KKK7', '450'), (3, '72752', '817'), (2, 'K2J32', '915'), (1, 'T25J7', '72'), (5, 'QQ6Q6', '53'), (2, '27T7J', '577'), (3, '98J89', '236'), (3, '23525', '404'), (6, '44244', '34'), (1, '2K8J7', '509'), (1, 'AK427', '108'), (2, '7K6KA', '466'), (2, '374J7', '553'), (4, '533K3', '78'), (1, '8J6K2', '301'), (4, 'J7577', '995'), (5, 'T88T8', '903'), (4, '626K6', '265'), (2, '2A96A', '462'), (1, 'T4987', '279'), (4, 'JJTKJ', '69'), (6, '77767', '641'), (4, '2Q232', ' ...

# %%
map = {
    "A": 14,
    "K": 13,
    "Q": 12,
    "J": 11,
    "T": 10,
}

# %%
for i in range(len(scores)):
    already_sorted = True
    for j in range(len(scores) - i - 1):
        if scores[j][0] < scores[j+1][0]:
            scores[j], scores[j+1] = scores[j+1], scores[j]
            already_sorted = False
        elif scores[j][0] == scores[j+1][0]:
            for k in range(5):
                val1 = int(scores[j][1][k]) if scores[j][1][k] not in map else map[scores[j][1][k]]
                val2 = int(scores[j+1][1][k]) if scores[j+1][1][k] not in map else map[scores[j+1][1][k]]
                if val1 < val2:
                    scores[j], scores[j+1] = scores[j+1], scores[j]
                    already_sorted = False
                    break
                elif val1 > val2:
                    break

    if already_sorted:
        break

print(scores)
# Out:
# [(7, 'JJJJJ', '647'), (6, 'AAAA4', '652'), (6, 'AAQAA', '883'), (6, 'AKAAA', '710'), (6, 'A8AAA', '388'), (6, 'KAKKK', '735'), (6, 'KKKKJ', '198'), (6, 'KKK8K', '491'), (6, 'KKK4K', '676'), (6, 'KK7KK', '745'), (6, 'KQKKK', '474'), (6, 'KTKKK', '422'), (6, 'K2KKK', '308'), (6, 'K2222', '184'), (6, 'QAQQQ', '640'), (6, 'QKQQQ', '261'), (6, 'QQQQT', '899'), (6, 'QQQ9Q', '228'), (6, 'QQQ4Q', '933'), (6, 'QQ7QQ', '362'), (6, 'QJQQQ', '89'), (6, 'QTTTT', '199'), (6, 'Q3QQQ', '358'), (6, 'JAAAA', '717'), (6, 'JJ8JJ', '868'), (6, 'JTTTT', '51'), (6, 'J6666', '188'), (6, 'J2222', '661'), (6, 'TKTTT', '174'), (6, 'TTTT9', '881'), (6, 'TTT4T', '56'), (6, 'TT6TT', '64'), (6, 'TT2TT', '792'), (6, 'T5TTT', '155'), (6, 'T2222', '714'), (6, '9A999', '825'), (6, '9KKKK', '556'), (6, '9999K', '268'), (6, '9999J', '617'), (6, '99959', '339'), (6, '99929', '119'), (6, '99899', '623'), (6, '96666', '521'), (6, '8K888', '782'), (6, '88J88', '916'), (6, '888T8', '772'), (6, '88882', '651'), (6, '88388', '987'), (6, '87777', '768'), (6, '86888', '294'), (6, '7AAAA', '926'), (6, '7TTTT', '483'), (6, '777K7', '202'), (6, '7777Q', '950'), (6, '7777J', '401'), (6, '7777T', '548'), (6, '77773', '451'), (6, '77767', '641'), (6, '76666', '9'), (6, '75555', '741'), (6, '72777', '347'), (6, '72222', '123'), (6, '66866', '192'), (6, '66366', '788'), (6, '66266', '918'), (6, '65666', '126'), (6, '63333', '711'), (6, '5Q555', '626'), (6, '57777', '248'), (6, '55A55', '356'), (6, '55J55', '270'), (6, '55565', '313'), (6, '5555K', '888'), (6, '55558', '100'), (6, '52555', '77'), (6, '47777', '929'), (6, '45555', '767'), (6, '44A44', '37'), (6, '44J44', '583'), (6, '44944', '68'), (6, '44844', '637'), (6, '44464', '820'), (6, '44454', '586'), (6, '44447', '546'), (6, '44244', '34'), (6, '34444', '720'), (6, '33Q33', '573'), (6, '333J3', '442'), (6, '33373', '859'), (6, '33353', '492'), (6, '29222', '606'), (6, '22422', '633'), (6, '22262', '540'), (5, 'AAA66', '173'), (5, 'AKKAA', '543'), (5, 'AJAJA', '66'), (5, 'ATATA', '514'), (5, 'A9A9A', '550'), (5, 'A88AA', '619'), (5, 'KAAKK', '911'), (5, 'KKQKQ', '445'), (5, 'K55KK', '624'), (5, 'K4KK4', '870'), (5, 'K3K3K', '283'), (5, 'QQQKK', '112'), (5, 'QQ6Q6', '53'), (5, 'Q77QQ', '756'), (5, 'Q5Q5Q', '245'), (5, 'Q4QQ4', '486'), (5, 'Q2QQ2', '753'), (5, 'Q222Q', '453'), (5, 'JJKKK', '366'), (5, 'JJQQQ', '333'), (5, 'J9JJ9', '713'), (5, 'J888J', '726'), (5, 'J77J7', '205'), (5, 'J666J', '596'), (5, 'J555J', '698'), (5, 'TATTA', '456'), (5, 'TTJTJ', '603'), (5, 'T88T8', '903'), (5, '9TTT9', '92'), (5, '99J9J', '129'), (5, '99944', '571'), (5, '98989', '526'), (5, '98898', '113'), (5, '96996', '25'), (5, '95599', '605'), (5, '8Q88Q', '555'), (5, '8J8JJ', '898'), (5, '88333', '701'), (5, '7AAA7', '152'), (5, '7A77A', '454'), (5, '7KKK7', '450'), (5, '7JJ7J', '88'), (5, '78878', '479'), (5, '77T7T', '399'), (5, '77979', '59'), (5, '777KK', '154'), (5, '77722', '467'), (5, '6KK6K', '136'), (5, '6QQ66', '158'), (5, '6J6JJ', '312'), (5, '68868', '998'), (5, '67677', '635'), (5, '67676', '481'), (5, '666AA', '706'), (5, '666KK', '750'), (5, '666TT', '844'), (5, '66555', '311'), (5, '64464', '574'), (5, '62622', '627'), (5, '5KK55', '678'), (5, '5T55T', '680'), (5, '59559', '722'), (5, '58585', '693'), (5, '57575', '296'), (5, '55AAA', '26'), (5, '55AA5', '780'), (5, '4AAA4', '432'), (5, '4Q44Q', '940'), (5, '44TTT', '781'), (5, '44884', '949'), (5, '44666', '387'), (5, '444JJ', '133'), (5, '44499', '775'), (5, '44477', '560'), (5, '44333', '478'), (5, '43443', '906'), (5, '42422', '744'), (5, '3AAA3', '160'), (5, '3QQQ3', '85'), (5, '3JJ33', '994'), (5, '3T3T3', '441'), (5, '37733', '18'), (5, '37377', '990'), (5, '36663', '799'), (5, '33TTT', '335'), (5, '33555', '402'), (5, '333AA', '382'), (5, '33355', '23'), (5, '32232', '873'), (5, '2K2KK', '137'), (5, '2J2J2', '322'), (5, '2TT22', '776'), (5, '2T2TT', '827'), (5, '28228', '61'), (5, '26662', '169'), (5, '23332', '629'), (5, '22AAA', '235'), (5, '22AA2', '201'), (5, '22K2 ...

# %%
sum = 0
for i, (_, _, bid) in enumerate(scores):
    print(len(scores) - i, bid)
    sum += int(bid) * (len(scores) - i)
sum
# Out:
# 1000 647
# 999 652
# 998 883
# 997 710
# 996 388
# 995 735
# 994 198
# 993 491
# 992 676
# 991 745
# 990 474
# 989 422
# 988 308
# 987 184
# 986 640
# 985 261
# 984 899
# 983 228
# 982 933
# 981 362
# 980 89
# 979 199
# 978 358
# 977 717
# 976 868
# 975 51
# 974 188
# 973 661
# 972 174
# 971 881
# 970 56
# 969 64
# 968 792
# 967 155
# 966 714
# 965 825
# 964 556
# 963 268
# 962 617
# 961 339
# 960 119
# 959 623
# 958 521
# 957 782
# 956 916
# 955 772
# 954 651
# 953 987
# 952 768
# 951 294
# 950 926
# 949 483
# 948 202
# 947 950
# 946 401
# 945 548
# 944 451
# 943 641
# 942 9
# 941 741
# 940 347
# 939 123
# 938 192
# 937 788
# 936 918
# 935 126
# 934 711
# 933 626
# 932 248
# 931 356
# 930 270
# 929 313
# 928 888
# 927 100
# 926 77
# 925 929
# 924 767
# 923 37
# 922 583
# 921 68
# 920 637
# 919 820
# 918 586
# 917 546
# 916 34
# 915 720
# 914 573
# 913 442
# 912 859
# 911 492
# 910 606
# 909 633
# 908 540
# 907 173
# 906 543
# 905 66
# 904 514
# 903 550
# 902 619
# 901 911
# 900 445
# 899 624
# 898 870
# 897 283
# 896 112
# 895 53
# 894 756
# 893 245
# 892 486
# 891 753
# 890 453
# 889 366
# 888 333
# 887 713
# 886 726
# 885 205
# 884 596
# 883 698
# 882 456
# 881 603
# 880 903
# 879 92
# 878 129
# 877 571
# 876 526
# 875 113
# 874 25
# 873 605
# 872 555
# 871 898
# 870 701
# 869 152
# 868 454
# 867 450
# 866 88
# 865 479
# 864 399
# 863 59
# 862 154
# 861 467
# 860 136
# 859 158
# 858 312
# 857 998
# 856 635
# 855 481
# 854 706
# 853 750
# 852 844
# 851 311
# 850 574
# 849 627
# 848 678
# 847 680
# 846 722
# 845 693
# 844 296
# 843 26
# 842 780
# 841 432
# 840 940
# 839 781
# 838 949
# 837 387
# 836 133
# 835 775
# 834 560
# 833 478
# 832 906
# 831 744
# 830 160
# 829 85
# 828 994
# 827 441
# 826 18
# 825 990
# 824 799
# 823 335
# 822 402
# 821 382
# 820 23
# 819 873
# 818 137
# 817 322
# 816 776
# 815 827
# 814 61
# 813 169
# 812 629
# 811 235
# 810 201
# 809 736
# 808 240
# 807 737
# 806 797
# 805 318
# 804 480
# 803 941
# 802 163
# 801 177
# 800 336
# 799 42
# 798 121
# 797 183
# 796 99
# 795 622
# 794 370
# 793 328
# 792 114
# 791 28
# 790 790
# 789 948
# 788 110
# 787 811
# 786 252
# 785 832
# 784 490
# 783 70
# 782 857
# 781 621
# 780 982
# 779 858
# 778 566
# 777 200
# 776 642
# 775 973
# 774 331
# 773 867
# 772 257
# 771 475
# 770 437
# 769 393
# 768 818
# 767 349
# 766 656
# 765 645
# 764 69
# 763 83
# 762 30
# 761 913
# 760 320
# 759 995
# 758 11
# 757 662
# 756 513
# 755 824
# 754 376
# 753 879
# 752 644
# 751 87
# 750 381
# 749 890
# 748 852
# 747 357
# 746 527
# 745 843
# 744 646
# 743 604
# 742 290
# 741 703
# 740 204
# 739 14
# 738 808
# 737 267
# 736 395
# 735 771
# 734 488
# 733 412
# 732 541
# 731 216
# 730 446
# 729 862
# 728 143
# 727 738
# 726 487
# 725 79
# 724 12
# 723 410
# 722 869
# 721 406
# 720 463
# 719 805
# 718 992
# 717 985
# 716 396
# 715 203
# 714 17
# 713 675
# 712 910
# 711 97
# 710 885
# 709 943
# 708 206
# 707 48
# 706 182
# 705 291
# 704 325
# 703 501
# 702 697
# 701 258
# 700 300
# 699 316
# 698 925
# 697 430
# 696 31
# 695 389
# 694 833
# 693 127
# 692 997
# 691 215
# 690 666
# 689 60
# 688 443
# 687 896
# 686 461
# 685 734
# 684 821
# 683 503
# 682 740
# 681 265
# 680 923
# 679 330
# 678 489
# 677 848
# 676 851
# 675 385
# 674 757
# 673 277
# 672 249
# 671 671
# 670 551
# 669 78
# 668 914
# 667 802
# 666 511
# 665 932
# 664 777
# 663 944
# 662 669
# 661 783
# 660 731
# 659 539
# 658 74
# 657 260
# 656 344
# 655 572
# 654 708
# 653 618
# 652 836
# 651 936
# 650 125
# 649 278
# 648 256
# 647 931
# 646 247
# 645 705
# 644 864
# 643 974
# 642 457
# 641 865
# 640 244
# 639 210
# 638 897
# 637 674
# 636 138
# 635 104
# 634 849
# 633 3
# 632 276
# 631 405
# 630 7
# 629 94
# 628 600
# 627 15
# 626 809
# 625 977
# 624 178
# 623 779
# 622 321
# 621 418
# 620 80
# 619 242
# 618 306
# 617 75
# 616 220
# 615 421
# 614 575
# 613 459
# 612 254
# 611 728
# 610 282
# 609 814
# 608 440
# 607 302
# 606 383
# 605 996
# 604 822
# 603 712
# 602 815
# 601 21
# 600 884
# 599 345
# 598 142
# 597 166
# 596 288
# 595 207
# 594 584
# 593 81
# 592 951
# 591 654
# 590 533
# 589 47
# 588 872
# 587 507
# 586 595
# 585 423
# 584 464
# 583 730
# 582 826
# 581 980
# 580 444
# 579 561
# 578 408
# 577 723
# 576 49
# 575 968
# 574 238
# 573 360
# 572 19
# 571 179
# 570 532
# 569 657
# 568 191
# 567 369
# 566 601
# 565 579
# 564 246
# 563 801
# 562 786
# 561 746
# 560 795
# 559 167
# 558 415
# 557 785
# 556 554
# 555 755
# 554 111
# 553 82
# 552 236
# 551 469
# 550 965
# 549 531
# 548 180
# 547 150
# 546 845
# 545 172
# 544 351
# 543 682
# 542 239
# 541 922
# 540 636
# 539 470
# 538 310
# 537 292
# 536 135
# 535 27
# 534 377
# 533 866
# 532 342
# 531 670
# 530 190
# 529 426
# 528 905
# 527 458
# 526 460
# 525 508
# 524 353
# 523 309
# 522 946
# 521 65
# 520 403
# 519 981
# 518 20
# 517 952
# 516 699
# 515 253
# 514 817
# 513 52
# 512 863
# 511 570
# 510 632
# 509 510
# 508 1000
# 507 41
# 506 499
# 505 893
# 504 494
# 503 762
# 502 212
# 501 262
# 500 506
# 499 747
# 498 537
# 497 520
# 496 63
# 495 598
# 494 477
# 493 164
# 492 91
# 491 677
# 490 791
# 489 518
# 488 962
# 487 733
# 486 544
# 485 975
# 484 495
# 483 613
# 482 187
# 481 515
# 480 874
# 479 354
# 478 778
# 477 33
# 476 638
# 475 196
# 474 272
# 473 967
# 472 304
# 471 685
# 470 213
# 469 758
# 468 120
# 467 2
# 466 139
# 465 673
# 464 4
# 463 891
# 462 610
# 461 616
# 460 186
# 459 193
# 458 684
# 457 562
# 456 691
# 455 614
# 454 971
# 453 875
# 452 989
# 451 681
# 450 846
# 449 516
# 448 716
# 447 847
# 446 355
# 445 702
# 444 293
# 443 438
# 442 517
# 441 625
# 440 404
# 439 38
# 438 424
# 437 615
# 436 392
# 435 118
# 434 643
# 433 650
# 432 578
# 431 763
# 430 45
# 429 963
# 428 719
# 427 749
# 426 159
# 425 871
# 424 43
# 423 812
# 422 739
# 421 284
# 420 195
# 419 765
# 418 471
# 417 937
# 416 390
# 415 696
# 414 837
# 413 251
# 412 639
# 411 73
# 410 748
# 409 909
# 408 485
# 407 22
# 406 834
# 405 400
# 404 853
# 403 482
# 402 162
# 401 340
# 400 912
# 399 915
# 398 286
# 397 585
# 396 838
# 395 524
# 394 427
# 393 449
# 392 106
# 391 102
# 390 368
# 389 448
# 388 831
# 387 476
# 386 525
# 385 602
# 384 170
# 383 317
# 382 769
# 381 876
# 380 764
# 379 904
# 378 597
# 377 224
# 376 271
# 375 165
# 374 839
# 373 957
# 372 519
# 371 465
# 370 323
# 369 225
# 368 631
# 367 935
# 366 341
# 365 986
# 364 877
# 363 101
# 362 71
# 361 819
# 360 530
# 359 493
# 358 297
# 357 743
# 356 773
# 355 945
# 354 688
# 353 151
# 352 707
# 351 117
# 350 810
# 349 908
# 348 299
# 347 103
# 346 394
# 345 972
# 344 378
# 343 966
# 342 10
# 341 54
# 340 219
# 339 751
# 338 504
# 337 774
# 336 659
# 335 386
# 334 840
# 333 416
# 332 46
# 331 529
# 330 115
# 329 364
# 328 970
# 327 648
# 326 798
# 325 928
# 324 319
# 323 55
# 322 472
# 321 803
# 320 161
# 319 828
# 318 372
# 317 589
# 316 147
# 315 329
# 314 361
# 313 379
# 312 683
# 311 658
# 310 466
# 309 804
# 308 307
# 307 829
# 306 407
# 305 588
# 304 695
# 303 679
# 302 919
# 301 789
# 300 796
# 299 591
# 298 241
# 297 134
# 296 334
# 295 567
# 294 264
# 293 208
# 292 274
# 291 303
# 290 435
# 289 185
# 288 107
# 287 156
# 286 984
# 285 413
# 284 221
# 283 880
# 282 732
# 281 289
# 280 580
# 279 856
# 278 727
# 277 295
# 276 57
# 275 611
# 274 498
# 273 545
# 272 557
# 271 664
# 270 324
# 269 927
# 268 343
# 267 502
# 266 226
# 265 281
# 264 217
# 263 350
# 262 729
# 261 672
# 260 564
# 259 582
# 258 93
# 257 496
# 256 8
# 255 581
# 254 367
# 253 255
# 252 770
# 251 62
# 250 956
# 249 237
# 248 721
# 247 374
# 246 473
# 245 243
# 244 793
# 243 233
# 242 955
# 241 594
# 240 227
# 239 365
# 238 993
# 237 131
# 236 144
# 235 958
# 234 411
# 233 692
# 232 149
# 231 807
# 230 634
# 229 663
# 228 429
# 227 830
# 226 380
# 225 553
# 224 263
# 223 934
# 222 569
# 221 409
# 220 599
# 219 141
# 218 428
# 217 462
# 216 991
# 215 766
# 214 854
# 213 559
# 212 275
# 211 375
# 210 222
# 209 346
# 208 209
# 207 577
# 206 280
# 205 420
# 204 1
# 203 816
# 202 930
# 201 961
# 200 6
# 199 425
# 198 86
# 197 214
# 196 108
# 195 468
# 194 538
# 193 287
# 192 609
# 191 35
# 190 704
# 189 16
# 188 500
# 187 145
# 186 988
# 185 999
# 184 686
# 183 687
# 182 44
# 181 759
# 180 189
# 179 665
# 178 298
# 177 29
# 176 285
# 175 558
# 174 484
# 173 924
# 172 835
# 171 218
# 170 976
# 169 942
# 168 653
# 167 592
# 166 505
# 165 436
# 164 549
# 163 969
# 162 96
# 161 620
# 160 850
# 159 24
# 158 784
# 157 628
# 156 352
# 155 168
# 154 754
# 153 109
# 152 563
# 151 901
# 150 273
# 149 67
# 148 718
# 147 536
# 146 608
# 145 305
# 144 36
# 143 76
# 142 552
# 141 348
# 140 607
# 139 894
# 138 455
# 137 326
# 136 882
# 135 568
# 134 900
# 133 231
# 132 397
# 131 983
# 130 122
# 129 279
# 128 535
# 127 938
# 126 752
# 125 823
# 124 921
# 123 72
# 122 157
# 121 522
# 120 667
# 119 398
# 118 861
# 117 878
# 116 391
# 115 433
# 114 920
# 113 700
# 112 587
# 111 419
# 110 90
# 109 917
# 108 146
# 107 959
# 106 332
# 105 528
# 104 301
# 103 175
# 102 761
# 101 39
# 100 612
# 99 314
# 98 234
# 97 889
# 96 171
# 95 497
# 94 512
# 93 58
# 92 5
# 91 534
# 90 523
# 89 194
# 88 964
# 87 787
# 86 153
# 85 953
# 84 95
# 83 895
# 82 960
# 81 660
# 80 384
# 79 855
# 78 266
# 77 140
# 76 371
# 75 978
# 74 902
# 73 841
# 72 130
# 71 176
# 70 947
# 69 230
# 68 40
# 67 630
# 66 565
# 65 689
# 64 98
# 63 649
# 62 337
# 61 124
# 60 887
# 59 434
# 58 84
# 57 593
# 56 417
# 55 128
# 54 939
# 53 452
# 52 315
# 51 547
# 50 590
# 49 148
# 48 800
# 47 742
# 46 269
# 45 842
# 44 886
# 43 542
# 42 327
# 41 105
# 40 32
# 39 892
# 38 806
# 37 813
# 36 668
# 35 907
# 34 431
# 33 259
# 32 690
# 31 576
# 30 860
# 29 760
# 28 116
# 27 132
# 26 50
# 25 223
# 24 338
# 23 373
# 22 715
# 21 794
# 20 725
# 19 694
# 18 709
# 17 13
# 16 232
# 15 509
# 14 229
# 13 447
# 12 414
# 11 439
# 10 655
# 9 954
# 8 363
# 7 211
# 6 197
# 5 181
# 4 724
# 3 979
# 2 250
# 1 359
# 250058342
