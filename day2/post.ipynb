# %%
[[draw.split() for draw in line.strip().split(": ")[1].split(", ")] for line in open("file.txt").readlines()]
# Out:
# [[['7', 'green'],
#   ['14', 'red'],
#   ['5', 'blue;', '8', 'red'],
#   ['4', 'green;', '6', 'green'],
#   ['18', 'red'],
#   ['9', 'blue']],
#  [['3', 'blue'],
#   ['15', 'red'],
#   ['5', 'green;', '1', 'blue'],
#   ['14', 'red'],
#   ['5', 'green;', '11', 'red;', '4', 'green'],
#   ['1', 'blue'],
#   ['3', 'red;', '4', 'green'],
#   ['1', 'blue;', '10', 'red'],
#   ['1', 'green']],
#  [['11', 'green'],
#   ['3', 'red;', '4', 'green'],
#   ['15', 'blue;', '14', 'blue'],
#   ['2', 'red'],
#   ['10', 'green;', '1', 'red'],
#   ['3', 'green'],
#   ['10', 'blue']],
#  [['1', 'green'],
#   ['6', 'red'],
#   ['11', 'blue;', '3', 'blue'],
#   ['12', 'red;', '1', 'green'],
#   ['14', 'red'],
#   ['8', 'blue;', '3', 'blue'],
#   ['7', 'red;', '8', 'blue'],
#   ['5', 'red;', '7', 'red'],
#   ['1', 'green']],
#  [['14', 'green'],
#   ['3', 'red'],
#   ['3', 'blue;', '2', 'red'],
#   ['1', 'green'],
#   ['1', 'blue;', '8', 'green'],
#   ['3', 'blue'],
#   ['1', 'red;', '15', 'green'],
# ...
